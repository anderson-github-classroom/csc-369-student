# %% [markdown]
# # Lab 5 - MongoDB Introduction

# %% [markdown]
# ## Disclaimer
#
# This lab has you work with current data about COVID-19 infections in the
# United States. This includes information about both infections, and deaths
# due to COVID-19. Some of the data is used to analyze the fatalities
# due to COVID-19 and compare them across time, and across different states.
# I am giving you this assignment because I feel learning about engineering and technology
# should be done with a greater purpose in mind. I understand fully that this
# may be a sensitive issue to some of you. Please reach out to me.

# %% [markdown]
# ## Introduction to pymongo
#
# We will be using pymongo for our mongo labs. For this first lab, we will be working through a subset of this tutorial (https://pymongo.readthedocs.io/en/stable/tutorial.html) on our own dataset.
#
# I have inserted ``data/daily.json`` into the database in the collection called ``daily`` in a database called ``csc-369``. You may gain access to it using the following commands:

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
db = client["csc-369"]

col = db["daily"]

# %% [markdown]
# You can take a look at one of the records using

# %%
import pprint
pprint.pprint(col.find_one())
# Out:
# {'_id': ObjectId('60392e3656264fee961ca816'),
#  'date': 20200405,
#  'dateChecked': '2020-04-05T20:00:00Z',
#  'death': 6,
#  'deathIncrease': 1,
#  'fips': '02',
#  'hash': '661d7b0f627847a2dceb5d70d4e9260965031cc2',
#  'hospitalized': 20,
#  'hospitalizedCumulative': 20,
#  'hospitalizedCurrently': None,
#  'hospitalizedIncrease': 4,
#  'inIcuCumulative': None,
#  'inIcuCurrently': None,
#  'negative': 6099,
#  'negativeIncrease': 230,
#  'onVentilatorCumulative': None,
#  'onVentilatorCurrently': None,
#  'pending': None,
#  'posNeg': 6284,
#  'positive': 185,
#  'positiveIncrease': 14,
#  'recovered': None,
#  'state': 'AK',
#  'total': 6284,
#  'totalTestResults': 6284,
#  'totalTestResultsIncrease': 244}

# %% [markdown]
# ## Information about the data
# The collection contains information about COVID-19
# infections in the United States. The data comes from the COVID Tracking
# Project web site, specifically, from this URL:
#
# https://covidtracking.com/api
#
# We will be using the JSON version of the daily US States data, available
# directly at this endpoint:
#
# https://covidtracking.com/api/states/daily
#
# For the sake of reproducibility, we will be using a data file Dr. Dekhtyar downloaded
# on April 5, that includes all available data from the beginning of the tracking (March 3, 2020) through April 5, 2020.
#
# The data file is available for download from the course web site.
# The COVID Tracking project Website describes the format of each JSON
# object in the collection as follows:
# * state - State or territory postal code abbreviation.
# * positive - Total cumulative positive test results.
# * positiveIncrease - Increase from the day before.
# * negative - Total cumulative negative test results.
# * negativeIncrease - Increase from the day before.
# * pending - Tests that have been submitted to a lab but no results have
# been reported yet.
# * totalTestResults - Calculated value (positive + negative) of total test
# results.
# * totalTestResultsIncrease - Increase from the day before.
# * hospitalized - Total cumulative number of people hospitalized.
# * hospitalizedIncrease - Increase from the day before.
# * death - Total cumulative number of people that have died.
# * deathIncrease - Increase from the day before.
# * dateChecked - ISO 8601 date of the time we saved visited their website
# * total - DEPRECATED Will be removed in the future. (positive + negative + pending). Pending has been an unstable value and should not count in any totals.
#
# In addition to these attributes, the JSON objects will contain the following
# attributes (explained elsewhere in the API documentation):
# * date - date for which the data is provided in the YYYYMMDD format
# (note: JSON treats this value as a number - make sure you parse
# correctly).
# * fips - Federal Information Processing Standard state code
# * hash - the hash code of the record
# * hospitalizedCurrently - number of people currently hospitalized
# * hospitalizedCumulative - appears to be the new name for the hospitalized attribute
# * inIcuCurrently - number of people currently in the ICU
# * inIcuCumulative - total cumulative number of people who required ICU hospitalization
# * onVentilatorCurrently - number of people currently on the ventilator
# * onVentilatorCumulative - total cumulative number of people who at some point were on ventilator
# * recovered - total cumulative number of people who recovered from COVID-19
#
# Note: ”DEPRECATED” attribute means an attribute that can be found
# in some of the earlier JSON records, that that is not found in the most
# recent ones.

# %% [markdown]
# I've noticed during interactions that some folks are skipping the line below. It is my fault for not explaining it. In Python when you import a file it is never reloaded even if the contents change on disk. If you run the cell below before an import, then it will reload automatically for you.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# make sure your run the cell above before running this
import Lab6_helper

# %% [markdown]
# **NOTE:** For this lab, I am working directly from the tutorial linked above. Solutions to this lab are modifications of commands you can find there.

# %% [markdown]
# **Exercise 1:** Use find_one to find a record with an object ID equal to 60392e3656264fee961ca817. As always, put your solution in Lab6_helper.

# %%
record = Lab6_helper.exercise_1(col,'60392e3656264fee961ca817')
record
# Out:
# {'_id': ObjectId('60392e3656264fee961ca817'),
#  'date': 20200405,
#  'state': 'AL',
#  'positive': 1796,
#  'negative': 11282,
#  'pending': None,
#  'hospitalizedCurrently': None,
#  'hospitalizedCumulative': 231,
#  'inIcuCurrently': None,
#  'inIcuCumulative': None,
#  'onVentilatorCurrently': None,
#  'onVentilatorCumulative': None,
#  'recovered': None,
#  'hash': '3f2c1f28926eeadf623d04aeb3716d29c5394d3c',
#  'dateChecked': '2020-04-05T20:00:00Z',
#  'death': 45,
#  'hospitalized': 231,
#  'total': 13078,
#  'totalTestResults': 13078,
#  'posNeg': 13078,
#  'fips': '01',
#  'deathIncrease': 2,
#  'hospitalizedIncrease': 19,
#  'negativeIncrease': 2009,
#  'positiveIncrease': 216,
#  'totalTestResultsIncrease': 2225}

# %% [markdown]
# **Exercise 2:** Use count_documents to count the number of records/documents that have ``state`` equal to 'CA'.

# %%
record = Lab6_helper.exercise_2(col,'CA')
record
# Out:
# 33

# %% [markdown]
# **Exercise 3:** Write a function that returns all of the documents that have a date less than ``d``. Sort the documents by the data, and convert the result to a list.

# %%
d = 20200315 # YYYY-MM-DD
record = Lab6_helper.exercise_3(col,d)
record
# Out:
# [{'_id': ObjectId('60392e3656264fee961caeb5'),
#   'date': 20200304,
#   'state': 'AZ',
#   'positive': 2,
#   'negative': 27,
#   'pending': 5,
#   'hash': 'f9b5336be00388e0549a6e35cfbe7ec911597df2',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 34,
#   'totalTestResults': 29,
#   'posNeg': 29,
#   'fips': '04',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb6'),
#   'date': 20200304,
#   'state': 'CA',
#   'positive': 53,
#   'negative': 462,
#   'hash': 'e89c69dcaf7f202257af579a58f86c340eee886a',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 515,
#   'totalTestResults': 515,
#   'posNeg': 515,
#   'fips': '06',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb7'),
#   'date': 20200304,
#   'state': 'FL',
#   'positive': 2,
#   'negative': 24,
#   'pending': 16,
#   'hash': '827f5f46040136c1b1901fef08f15b03805c57f5',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 42,
#   'totalTestResults': 26,
#   'posNeg': 26,
#   'fips': '12',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb8'),
#   'date': 20200304,
#   'state': 'GA',
#   'positive': 2,
#   'hash': '5a4b97663e22df521e97a56f67c3f458eafb2e59',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 2,
#   'totalTestResults': 2,
#   'posNeg': 2,
#   'fips': '13',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb9'),
#   'date': 20200304,
#   'state': 'IL',
#   'positive': 4,
#   'negative': 124,
#   'pending': 27,
#   'hash': 'c99302904c1de329aeb568cdf92affb6dd5921ad',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 155,
#   'totalTestResults': 128,
#   'posNeg': 128,
#   'fips': '17',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeba'),
#   'date': 20200304,
#   'state': 'MA',
#   'positive': 2,
#   'hash': '36d8d4b1b34007477b562a078613309f63e7bd0e',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 2,
#   'totalTestResults': 2,
#   'posNeg': 2,
#   'fips': '25',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caebb'),
#   'date': 20200304,
#   'state': 'NC',
#   'positive': 1,
#   'hash': '0361de92db7c1867144ce35f0d61e1588f3a13d5',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '37',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caebc'),
#   'date': 20200304,
#   'state': 'NH',
#   'positive': 2,
#   'negative': 10,
#   'pending': 7,
#   'hash': '57c57bb5f40efbba8ab043701700324b09ac602d',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 19,
#   'totalTestResults': 12,
#   'posNeg': 12,
#   'fips': '33',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caebd'),
#   'date': 20200304,
#   'state': 'NY',
#   'positive': 6,
#   'negative': 48,
#   'pending': 24,
#   'hash': '0e095e2b3db515b00d892276e6cac6912b1e0111',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 78,
#   'totalTestResults': 54,
#   'posNeg': 54,
#   'fips': '36',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caebe'),
#   'date': 20200304,
#   'state': 'OR',
#   'positive': 3,
#   'negative': 29,
#   'pending': 18,
#   'hash': 'd63f4cf486a6d2f86062b9af1bd46955abd90cb9',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 50,
#   'totalTestResults': 32,
#   'posNeg': 32,
#   'fips': '41',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caebf'),
#   'date': 20200304,
#   'state': 'SC',
#   'positive': 0,
#   'negative': 5,
#   'pending': 0,
#   'hash': '012fa30a9958580f589eb7d1de5e5a81c327b1a5',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 5,
#   'totalTestResults': 5,
#   'posNeg': 5,
#   'fips': '45',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caec0'),
#   'date': 20200304,
#   'state': 'TX',
#   'positive': 1,
#   'hash': 'd29839e81cae6ba53df2d1a1d7bfeddfd4fc8509',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '48',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caec1'),
#   'date': 20200304,
#   'state': 'WA',
#   'positive': 39,
#   'negative': None,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'hash': 'e07bd12171fed21351784c462b0dab23d8cfabbd',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'death': 10,
#   'hospitalized': None,
#   'total': 39,
#   'totalTestResults': 39,
#   'posNeg': 39,
#   'fips': '53',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caec2'),
#   'date': 20200304,
#   'state': 'WI',
#   'positive': 1,
#   'negative': 19,
#   'pending': 6,
#   'hash': 'c1fede94be9a426dc9c3b5d26d33b9f168fec21c',
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'total': 26,
#   'totalTestResults': 20,
#   'posNeg': 20,
#   'fips': '55',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae9d'),
#   'date': 20200305,
#   'state': 'AZ',
#   'positive': 2,
#   'negative': 28,
#   'pending': 6,
#   'hash': '3e94b739062d1c0306f5279361451cd382171ccf',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 36,
#   'totalTestResults': 30,
#   'posNeg': 30,
#   'fips': '04',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 1,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 1},
#  {'_id': ObjectId('60392e3656264fee961cae9e'),
#   'date': 20200305,
#   'state': 'CA',
#   'positive': 53,
#   'negative': 462,
#   'hash': 'ce0755ed64d8d97da631569ac60cacb5e301a000',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 515,
#   'totalTestResults': 515,
#   'posNeg': 515,
#   'fips': '06',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae9f'),
#   'date': 20200305,
#   'state': 'CO',
#   'positive': 0,
#   'negative': 19,
#   'pending': 21,
#   'hash': 'e45a58fa7b4795ecc217438ff041a6bd2b925fe3',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 40,
#   'totalTestResults': 19,
#   'posNeg': 19,
#   'fips': '08',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caea0'),
#   'date': 20200305,
#   'state': 'DC',
#   'positive': 0,
#   'negative': 6,
#   'pending': 2,
#   'hash': '86141ea62e1c9a456849cf2f2196a31ac9669154',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 8,
#   'totalTestResults': 6,
#   'posNeg': 6,
#   'fips': '11',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caea1'),
#   'date': 20200305,
#   'state': 'FL',
#   'positive': 9,
#   'negative': 31,
#   'pending': 69,
#   'hash': 'd7d91ffc92fbbfad57ff361b0193d3f7df25b958',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 109,
#   'totalTestResults': 40,
#   'posNeg': 40,
#   'fips': '12',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 7,
#   'positiveIncrease': 7,
#   'totalTestResultsIncrease': 14},
#  {'_id': ObjectId('60392e3656264fee961caea2'),
#   'date': 20200305,
#   'state': 'GA',
#   'positive': 2,
#   'hash': '4247fbf0514b9492027b2328f3f2dc0b2e45f063',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 2,
#   'totalTestResults': 2,
#   'posNeg': 2,
#   'fips': '13',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caea3'),
#   'date': 20200305,
#   'state': 'IL',
#   'positive': 5,
#   'negative': 165,
#   'pending': 27,
#   'hash': 'b4c9428d01eee9c65c8053a8cd8af2b28f9d7440',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 197,
#   'totalTestResults': 170,
#   'posNeg': 170,
#   'fips': '17',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 41,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 42},
#  {'_id': ObjectId('60392e3656264fee961caea4'),
#   'date': 20200305,
#   'state': 'MA',
#   'positive': 2,
#   'hash': 'ad6e88d352dfa8b8f0dd1bf41a2c506911f25bc0',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 2,
#   'totalTestResults': 2,
#   'posNeg': 2,
#   'fips': '25',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caea5'),
#   'date': 20200305,
#   'state': 'MD',
#   'positive': 0,
#   'negative': 17,
#   'pending': 14,
#   'hash': '0d90494b997e148552cd6034f5f347e1d5afb802',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 31,
#   'totalTestResults': 17,
#   'posNeg': 17,
#   'fips': '24',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caea6'),
#   'date': 20200305,
#   'state': 'MI',
#   'positive': 0,
#   'negative': 8,
#   'pending': 0,
#   'hash': 'dd366e6ea7f02c3c5a0f1f0639f3af9396fd0905',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 8,
#   'totalTestResults': 8,
#   'posNeg': 8,
#   'fips': '26',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caea7'),
#   'date': 20200305,
#   'state': 'NC',
#   'positive': 1,
#   'hash': 'd3f8875e94e71c97de0283327b26f1feca9172e0',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '37',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caea8'),
#   'date': 20200305,
#   'state': 'NE',
#   'positive': 0,
#   'negative': 17,
#   'pending': 5,
#   'hash': '5a0d06bda6fe7a3d859877a222126a595c97fc61',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 22,
#   'totalTestResults': 17,
#   'posNeg': 17,
#   'fips': '31',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caea9'),
#   'date': 20200305,
#   'state': 'NH',
#   'positive': 2,
#   'negative': 16,
#   'pending': 4,
#   'hash': '7e34f4dacfe1b54e984b2725002f97e08fbae32d',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 22,
#   'totalTestResults': 18,
#   'posNeg': 18,
#   'fips': '33',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 6,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 6},
#  {'_id': ObjectId('60392e3656264fee961caeaa'),
#   'date': 20200305,
#   'state': 'NJ',
#   'positive': 1,
#   'hash': '80fa3d5297f9e2b3a46fa82bf816c002d9da0976',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '34',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeab'),
#   'date': 20200305,
#   'state': 'NV',
#   'positive': 1,
#   'negative': 14,
#   'hash': 'c75ee774e7c6ee7ca098db7e8bdd27109e94471a',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 15,
#   'totalTestResults': 15,
#   'posNeg': 15,
#   'fips': '32',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeac'),
#   'date': 20200305,
#   'state': 'NY',
#   'positive': 22,
#   'negative': 76,
#   'pending': 24,
#   'hash': 'a5eb1a3c895ee3acd8c87b19363bab6d581b3933',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 122,
#   'totalTestResults': 98,
#   'posNeg': 98,
#   'fips': '36',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 28,
#   'positiveIncrease': 16,
#   'totalTestResultsIncrease': 44},
#  {'_id': ObjectId('60392e3656264fee961caead'),
#   'date': 20200305,
#   'state': 'OH',
#   'positive': 0,
#   'negative': 7,
#   'pending': 3,
#   'hash': '1bbd3319a4e6db7805828c6b8588392ceb2ad0f0',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 10,
#   'totalTestResults': 7,
#   'posNeg': 7,
#   'fips': '39',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeae'),
#   'date': 20200305,
#   'state': 'OR',
#   'positive': 3,
#   'negative': 45,
#   'pending': 13,
#   'hash': '99211bd19ed97ed9d4cf2ff512e5df794b13f3b8',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 61,
#   'totalTestResults': 48,
#   'posNeg': 48,
#   'fips': '41',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 16,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 16},
#  {'_id': ObjectId('60392e3656264fee961caeaf'),
#   'date': 20200305,
#   'state': 'SC',
#   'positive': 0,
#   'negative': 5,
#   'pending': 0,
#   'hash': '4ebec78070f45d9a5e6257d3ec1b1c20b6618cb1',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 5,
#   'totalTestResults': 5,
#   'posNeg': 5,
#   'fips': '45',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caeb0'),
#   'date': 20200305,
#   'state': 'TN',
#   'positive': 1,
#   'hash': 'd6b98cde0f741d1de22a669e2bcbdd2455e12b8a',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '47',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb1'),
#   'date': 20200305,
#   'state': 'TX',
#   'positive': 1,
#   'hash': 'd7dc50f88fb103b81e0745b9f7824ed7ee6c1738',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '48',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caeb2'),
#   'date': 20200305,
#   'state': 'VA',
#   'positive': 0,
#   'negative': 18,
#   'pending': 3,
#   'hash': 'c34566b6ec1573923e494c44f1c6b744fed9b3ad',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 21,
#   'totalTestResults': 18,
#   'posNeg': 18,
#   'fips': '51',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb3'),
#   'date': 20200305,
#   'state': 'WA',
#   'positive': 70,
#   'negative': None,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'hash': 'dfe5b036415333cb6e796cd8bde4805a159d6676',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'death': 11,
#   'hospitalized': None,
#   'total': 70,
#   'totalTestResults': 70,
#   'posNeg': 70,
#   'fips': '53',
#   'deathIncrease': 1,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 31,
#   'totalTestResultsIncrease': 31},
#  {'_id': ObjectId('60392e3656264fee961caeb4'),
#   'date': 20200305,
#   'state': 'WI',
#   'positive': 1,
#   'negative': 19,
#   'pending': 6,
#   'hash': '3620b6a39cef411a89d895ac830c5c954ce63541',
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'total': 26,
#   'totalTestResults': 20,
#   'posNeg': 20,
#   'fips': '55',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae79'),
#   'date': 20200306,
#   'state': 'AK',
#   'positive': 0,
#   'negative': 8,
#   'pending': 1,
#   'hash': 'b95ff00414e9a5542ba2aa08fdfda0b023c7c69c',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 9,
#   'totalTestResults': 8,
#   'posNeg': 8,
#   'fips': '02',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae7a'),
#   'date': 20200306,
#   'state': 'AR',
#   'positive': 0,
#   'negative': 6,
#   'pending': 0,
#   'hash': 'baadb217d3fcf5f4811488adcd8f345a2a29e391',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 6,
#   'totalTestResults': 6,
#   'posNeg': 6,
#   'fips': '05',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae7b'),
#   'date': 20200306,
#   'state': 'AZ',
#   'positive': 3,
#   'negative': 33,
#   'pending': 15,
#   'hash': 'bcfcf56b97c3f10a640d25f6148abbc1f17fa07d',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 51,
#   'totalTestResults': 36,
#   'posNeg': 36,
#   'fips': '04',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 5,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 6},
#  {'_id': ObjectId('60392e3656264fee961cae7c'),
#   'date': 20200306,
#   'state': 'CA',
#   'positive': 60,
#   'negative': 462,
#   'hash': 'ed5984edee3bf6ee9bc3b89bc15e52f3bdade592',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 522,
#   'totalTestResults': 522,
#   'posNeg': 522,
#   'fips': '06',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 7,
#   'totalTestResultsIncrease': 7},
#  {'_id': ObjectId('60392e3656264fee961cae7d'),
#   'date': 20200306,
#   'state': 'CO',
#   'positive': 2,
#   'negative': 46,
#   'pending': 30,
#   'hash': '2affe95a8de9524f8e77344a5a354729331024fa',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 78,
#   'totalTestResults': 48,
#   'posNeg': 48,
#   'fips': '08',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 27,
#   'positiveIncrease': 2,
#   'totalTestResultsIncrease': 29},
#  {'_id': ObjectId('60392e3656264fee961cae7e'),
#   'date': 20200306,
#   'state': 'DC',
#   'positive': 0,
#   'negative': 8,
#   'pending': 1,
#   'hash': '0916c062b23fb7dafb1a661e9e93554b146102bc',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 9,
#   'totalTestResults': 8,
#   'posNeg': 8,
#   'fips': '11',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 2,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 2},
#  {'_id': ObjectId('60392e3656264fee961cae7f'),
#   'date': 20200306,
#   'state': 'DE',
#   'positive': 0,
#   'negative': 10,
#   'pending': 0,
#   'hash': 'ce64a0188bd545e3f624bf5c958ad5a308f7c042',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 10,
#   'totalTestResults': 10,
#   'posNeg': 10,
#   'fips': '10',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae80'),
#   'date': 20200306,
#   'state': 'FL',
#   'positive': 9,
#   'negative': 55,
#   'pending': 51,
#   'hash': 'ec1d19fd312871b78238dee947a1614eb253b818',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 115,
#   'totalTestResults': 64,
#   'posNeg': 64,
#   'fips': '12',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 24,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 24},
#  {'_id': ObjectId('60392e3656264fee961cae81'),
#   'date': 20200306,
#   'state': 'GA',
#   'positive': 2,
#   'hash': 'd6ae73ad152b1a4b8de98e45e77180669400ec85',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 2,
#   'totalTestResults': 2,
#   'posNeg': 2,
#   'fips': '13',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae82'),
#   'date': 20200306,
#   'state': 'IA',
#   'positive': 0,
#   'negative': 15,
#   'pending': 2,
#   'hash': '73ace108c09e0e8391d16fb4cc771e1dd2107a8a',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 17,
#   'totalTestResults': 15,
#   'posNeg': 15,
#   'fips': '19',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae83'),
#   'date': 20200306,
#   'state': 'IL',
#   'positive': 5,
#   'negative': 180,
#   'pending': 35,
#   'hash': 'cea4d67d62c223cc0e6e983c16ec4eb1e7e287e7',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 220,
#   'totalTestResults': 185,
#   'posNeg': 185,
#   'fips': '17',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 15,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 15},
#  {'_id': ObjectId('60392e3656264fee961cae84'),
#   'date': 20200306,
#   'state': 'IN',
#   'positive': 1,
#   'hash': '57d3744352ffb9db87fd1bf34f0a80df811443d2',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '18',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae85'),
#   'date': 20200306,
#   'state': 'KS',
#   'positive': 0,
#   'negative': 4,
#   'pending': 0,
#   'hash': '69d9379255fba9dc0e12dc3d34568cf662050519',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 4,
#   'totalTestResults': 4,
#   'posNeg': 4,
#   'fips': '20',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae86'),
#   'date': 20200306,
#   'state': 'KY',
#   'positive': 0,
#   'negative': 7,
#   'pending': 3,
#   'hash': 'd14490bb62ff36a14f6d7d3983dcc37a6213f306',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 10,
#   'totalTestResults': 7,
#   'posNeg': 7,
#   'fips': '21',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae87'),
#   'date': 20200306,
#   'state': 'MA',
#   'positive': 8,
#   'hash': 'ba07a81180b3f869f4fc9a15473d56c77bda4a58',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 8,
#   'totalTestResults': 8,
#   'posNeg': 8,
#   'fips': '25',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 6,
#   'totalTestResultsIncrease': 6},
#  {'_id': ObjectId('60392e3656264fee961cae88'),
#   'date': 20200306,
#   'state': 'MD',
#   'positive': 3,
#   'negative': 26,
#   'pending': 12,
#   'hash': '1fa11fd8e4ccf23cd88dad0abf8f2ed09692b6f7',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 41,
#   'totalTestResults': 29,
#   'posNeg': 29,
#   'fips': '24',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 9,
#   'positiveIncrease': 3,
#   'totalTestResultsIncrease': 12},
#  {'_id': ObjectId('60392e3656264fee961cae89'),
#   'date': 20200306,
#   'state': 'MI',
#   'positive': 0,
#   'negative': 8,
#   'pending': 8,
#   'hash': '21d52a1d42c23fa0a2597c8982b999e849f6f5ae',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 16,
#   'totalTestResults': 8,
#   'posNeg': 8,
#   'fips': '26',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae8a'),
#   'date': 20200306,
#   'state': 'MN',
#   'positive': 0,
#   'negative': 36,
#   'hash': 'e5132c799bd8a985ee5eebaa58cc91fe172d2252',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 36,
#   'totalTestResults': 36,
#   'posNeg': 36,
#   'fips': '27',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae8b'),
#   'date': 20200306,
#   'state': 'NC',
#   'positive': 2,
#   'hash': '7dc32933c444ad3ead82aae5b70360d952aa26f5',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 2,
#   'totalTestResults': 2,
#   'posNeg': 2,
#   'fips': '37',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 1},
#  {'_id': ObjectId('60392e3656264fee961cae8c'),
#   'date': 20200306,
#   'state': 'NE',
#   'positive': 0,
#   'negative': 17,
#   'pending': 5,
#   'hash': 'f6a3dae478e443059d53552df4bcdfcbf1df1562',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 22,
#   'totalTestResults': 17,
#   'posNeg': 17,
#   'fips': '31',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae8d'),
#   'date': 20200306,
#   'state': 'NH',
#   'positive': 2,
#   'negative': 20,
#   'pending': 3,
#   'hash': 'cb6d3e65ea48c1b73ea053bd4fff5effe820cd79',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 25,
#   'totalTestResults': 22,
#   'posNeg': 22,
#   'fips': '33',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 4,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 4},
#  {'_id': ObjectId('60392e3656264fee961cae8e'),
#   'date': 20200306,
#   'state': 'NJ',
#   'positive': 1,
#   'hash': 'c1ebdfb1febe7a106dd31b8742d983a21185c3bf',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '34',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae8f'),
#   'date': 20200306,
#   'state': 'NM',
#   'positive': 0,
#   'negative': 16,
#   'pending': 0,
#   'hash': 'a7fdde839cc24edda883ae6eded317516823f0d3',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 16,
#   'totalTestResults': 16,
#   'posNeg': 16,
#   'fips': '35',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae90'),
#   'date': 20200306,
#   'state': 'NV',
#   'positive': 1,
#   'negative': 14,
#   'hash': '987c6d506024afbec19c37ec86dbb2f36578a842',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 15,
#   'totalTestResults': 15,
#   'posNeg': 15,
#   'fips': '32',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae91'),
#   'date': 20200306,
#   'state': 'NY',
#   'positive': 33,
#   'negative': 92,
#   'pending': 236,
#   'hash': '18e7306085561597629e7ffac110572b1aa9f9e5',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 361,
#   'totalTestResults': 125,
#   'posNeg': 125,
#   'fips': '36',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 16,
#   'positiveIncrease': 11,
#   'totalTestResultsIncrease': 27},
#  {'_id': ObjectId('60392e3656264fee961cae92'),
#   'date': 20200306,
#   'state': 'OH',
#   'positive': 0,
#   'negative': 8,
#   'pending': 2,
#   'hash': '053530986545d47250674a6c7891318414ac402d',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 10,
#   'totalTestResults': 8,
#   'posNeg': 8,
#   'fips': '39',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 1,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 1},
#  {'_id': ObjectId('60392e3656264fee961cae93'),
#   'date': 20200306,
#   'state': 'OR',
#   'positive': 3,
#   'negative': 64,
#   'pending': 28,
#   'hash': '8c2cf703264be22af405b67f312c031ee48a2c49',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 95,
#   'totalTestResults': 67,
#   'posNeg': 67,
#   'fips': '41',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 19,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 19},
#  {'_id': ObjectId('60392e3656264fee961cae94'),
#   'date': 20200306,
#   'state': 'PA',
#   'positive': 2,
#   'hash': '3ce04ca60daa0171a4965e6870cd5710345e8669',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 2,
#   'totalTestResults': 2,
#   'posNeg': 2,
#   'fips': '42',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae95'),
#   'date': 20200306,
#   'state': 'SC',
#   'positive': 0,
#   'negative': 5,
#   'pending': 0,
#   'hash': '9fa8b0c526fc589b40d7b5af245bc0988d3b9c56',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 5,
#   'totalTestResults': 5,
#   'posNeg': 5,
#   'fips': '45',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae96'),
#   'date': 20200306,
#   'state': 'TN',
#   'positive': 1,
#   'hash': 'c08f2fdfc2a48fde032229c9b4181788db59f9f3',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '47',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae97'),
#   'date': 20200306,
#   'state': 'TX',
#   'positive': 5,
#   'hash': 'cd363e289639a9dfe6b4575b0f64f46900a7901b',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 5,
#   'totalTestResults': 5,
#   'posNeg': 5,
#   'fips': '48',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 4,
#   'totalTestResultsIncrease': 4},
#  {'_id': ObjectId('60392e3656264fee961cae98'),
#   'date': 20200306,
#   'state': 'VA',
#   'positive': 0,
#   'negative': 21,
#   'pending': 10,
#   'hash': 'd226abb632c34f9036421499b7f6c7bc248bb483',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 31,
#   'totalTestResults': 21,
#   'posNeg': 21,
#   'fips': '51',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 3,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 3},
#  {'_id': ObjectId('60392e3656264fee961cae99'),
#   'date': 20200306,
#   'state': 'VT',
#   'positive': 0,
#   'negative': 8,
#   'hash': 'a4dec17604c465729da7a9dfe9e9ec4426c32672',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 8,
#   'totalTestResults': 8,
#   'posNeg': 8,
#   'fips': '50',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae9a'),
#   'date': 20200306,
#   'state': 'WA',
#   'positive': 79,
#   'negative': 370,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'hash': 'acf1e359af09f765bfb51daff2037013e6dcb7ef',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'death': 14,
#   'hospitalized': None,
#   'total': 449,
#   'totalTestResults': 449,
#   'posNeg': 449,
#   'fips': '53',
#   'deathIncrease': 3,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 370,
#   'positiveIncrease': 9,
#   'totalTestResultsIncrease': 379},
#  {'_id': ObjectId('60392e3656264fee961cae9b'),
#   'date': 20200306,
#   'state': 'WI',
#   'positive': 1,
#   'negative': 31,
#   'pending': 12,
#   'hash': 'b96ccd39757d6ceed4a2d639e0095b3d8f8f3434',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 44,
#   'totalTestResults': 32,
#   'posNeg': 32,
#   'fips': '55',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 12,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 12},
#  {'_id': ObjectId('60392e3656264fee961cae9c'),
#   'date': 20200306,
#   'state': 'WV',
#   'positive': 0,
#   'negative': 1,
#   'pending': 4,
#   'hash': '68d062b16bb06f20eabeb52ee79544ec7a511018',
#   'dateChecked': '2020-03-06T21:00:00Z',
#   'total': 5,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '54',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae46'),
#   'date': 20200307,
#   'state': 'AK',
#   'positive': 0,
#   'negative': 12,
#   'pending': 2,
#   'hash': '71953eb42494f6000afda41cda80b1b3dc836a83',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 14,
#   'totalTestResults': 12,
#   'posNeg': 12,
#   'fips': '02',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 4,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 4},
#  {'_id': ObjectId('60392e3656264fee961cae47'),
#   'date': 20200307,
#   'state': 'AL',
#   'positive': 0,
#   'hash': '1d94a3b00af81e57b35a00c0eeaa339ec76d962a',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 0,
#   'totalTestResults': 0,
#   'posNeg': 0,
#   'fips': '01',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae48'),
#   'date': 20200307,
#   'state': 'AR',
#   'positive': 0,
#   'negative': 6,
#   'pending': 0,
#   'hash': 'bdba8d05662d7b38e7309c5baa49cd20b63a536b',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 6,
#   'totalTestResults': 6,
#   'posNeg': 6,
#   'fips': '05',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae49'),
#   'date': 20200307,
#   'state': 'AZ',
#   'positive': 5,
#   'negative': 44,
#   'pending': 7,
#   'hash': '0c334b56af3108711bb907f46599a84bd536ac1d',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 56,
#   'totalTestResults': 49,
#   'posNeg': 49,
#   'fips': '04',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 11,
#   'positiveIncrease': 2,
#   'totalTestResultsIncrease': 13},
#  {'_id': ObjectId('60392e3656264fee961cae4a'),
#   'date': 20200307,
#   'state': 'CA',
#   'positive': 69,
#   'negative': 462,
#   'hash': '311a213f5744c6b33147c107519218e8d9f55d23',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 531,
#   'totalTestResults': 531,
#   'posNeg': 531,
#   'fips': '06',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 9,
#   'totalTestResultsIncrease': 9},
#  {'_id': ObjectId('60392e3656264fee961cae4b'),
#   'date': 20200307,
#   'state': 'CO',
#   'positive': 8,
#   'negative': 55,
#   'pending': 69,
#   'hash': 'b3e767a79aa144a708ff8d26dd77311725722068',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 132,
#   'totalTestResults': 63,
#   'posNeg': 63,
#   'fips': '08',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 9,
#   'positiveIncrease': 6,
#   'totalTestResultsIncrease': 15},
#  {'_id': ObjectId('60392e3656264fee961cae4c'),
#   'date': 20200307,
#   'state': 'CT',
#   'positive': 0,
#   'hash': 'd9e680a00789072a49cb76e097d4229667366ed7',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 0,
#   'totalTestResults': 0,
#   'posNeg': 0,
#   'fips': '09',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae4d'),
#   'date': 20200307,
#   'state': 'DC',
#   'positive': 0,
#   'negative': 8,
#   'pending': 1,
#   'hash': 'e11c537902c2e50281d5f0474f9627885a7d2687',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 9,
#   'totalTestResults': 8,
#   'posNeg': 8,
#   'fips': '11',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae4e'),
#   'date': 20200307,
#   'state': 'DE',
#   'positive': 0,
#   'negative': 10,
#   'pending': 0,
#   'hash': '7eadaaa0b57573c2bdbc9a8e6cb4491819bdebe3',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 10,
#   'totalTestResults': 10,
#   'posNeg': 10,
#   'fips': '10',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae4f'),
#   'date': 20200307,
#   'state': 'FL',
#   'positive': 14,
#   'negative': 100,
#   'pending': 88,
#   'hash': '8e5302ac32c92ff9ad0d33eac5dbb7fadb2633fc',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 202,
#   'totalTestResults': 114,
#   'posNeg': 114,
#   'fips': '12',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 45,
#   'positiveIncrease': 5,
#   'totalTestResultsIncrease': 50},
#  {'_id': ObjectId('60392e3656264fee961cae50'),
#   'date': 20200307,
#   'state': 'GA',
#   'positive': 6,
#   'hash': '300c65424c0683e4fe3b738ffa83c73e6e166987',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 6,
#   'totalTestResults': 6,
#   'posNeg': 6,
#   'fips': '13',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 4,
#   'totalTestResultsIncrease': 4},
#  {'_id': ObjectId('60392e3656264fee961cae51'),
#   'date': 20200307,
#   'state': 'HI',
#   'positive': 1,
#   'hash': 'fdf9b14d1375f62ec31807e17621275a28a68e35',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '15',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae52'),
#   'date': 20200307,
#   'state': 'IA',
#   'positive': 0,
#   'negative': 15,
#   'pending': 2,
#   'hash': '57014c410bdcf67c766c3bde093c62bf971bf561',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 17,
#   'totalTestResults': 15,
#   'posNeg': 15,
#   'fips': '19',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae53'),
#   'date': 20200307,
#   'state': 'ID',
#   'positive': 0,
#   'negative': 27,
#   'hash': '4f4e0071fd17623d671266cb5b4d8f4a998e7635',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 27,
#   'totalTestResults': 27,
#   'posNeg': 27,
#   'fips': '16',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae54'),
#   'date': 20200307,
#   'state': 'IL',
#   'positive': 6,
#   'negative': 191,
#   'pending': 44,
#   'hash': '0617c3d41d4b13ac629144876a75a2d391036742',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 241,
#   'totalTestResults': 197,
#   'posNeg': 197,
#   'fips': '17',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 11,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 12},
#  {'_id': ObjectId('60392e3656264fee961cae55'),
#   'date': 20200307,
#   'state': 'IN',
#   'positive': 1,
#   'hash': '341ab30a48c34775d1b7fb9b4a82dea3d4bdff65',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '18',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae56'),
#   'date': 20200307,
#   'state': 'KS',
#   'positive': 0,
#   'negative': 11,
#   'pending': 2,
#   'hash': '3423d332e782b75c00baf7159c3aa95ea8927439',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 13,
#   'totalTestResults': 11,
#   'posNeg': 11,
#   'fips': '20',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 7,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 7},
#  {'_id': ObjectId('60392e3656264fee961cae57'),
#   'date': 20200307,
#   'state': 'KY',
#   'positive': 1,
#   'negative': 9,
#   'hash': '48c3d48fed83cfd2f32e9dbf06e7e1410d3e0fe6',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 10,
#   'totalTestResults': 10,
#   'posNeg': 10,
#   'fips': '21',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 2,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 3},
#  {'_id': ObjectId('60392e3656264fee961cae58'),
#   'date': 20200307,
#   'state': 'LA',
#   'positive': 0,
#   'hash': 'b7526761c843e52a6bd2a5e89719a7ed71cc0b5e',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 0,
#   'totalTestResults': 0,
#   'posNeg': 0,
#   'fips': '22',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae59'),
#   'date': 20200307,
#   'state': 'MA',
#   'positive': 13,
#   'hash': 'b919208fee55fb337773b232ea6298e5465a717d',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 13,
#   'totalTestResults': 13,
#   'posNeg': 13,
#   'fips': '25',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 5,
#   'totalTestResultsIncrease': 5},
#  {'_id': ObjectId('60392e3656264fee961cae5a'),
#   'date': 20200307,
#   'state': 'MD',
#   'positive': 3,
#   'negative': 41,
#   'hash': 'b2d7275372012956019c1ac4675a486072ad50c0',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 44,
#   'totalTestResults': 44,
#   'posNeg': 44,
#   'fips': '24',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 15,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 15},
#  {'_id': ObjectId('60392e3656264fee961cae5b'),
#   'date': 20200307,
#   'state': 'ME',
#   'positive': 0,
#   'negative': 1,
#   'hash': '78aa7cd66f9ed0076403ca7ace6b9725577d669a',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 1,
#   'totalTestResults': 1,
#   'posNeg': 1,
#   'fips': '23',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae5c'),
#   'date': 20200307,
#   'state': 'MI',
#   'positive': 0,
#   'negative': 18,
#   'pending': 9,
#   'hash': '3d2c72d07bd5dc6c02a4b44769d5b0e186861cbf',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 27,
#   'totalTestResults': 18,
#   'posNeg': 18,
#   'fips': '26',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 10,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 10},
#  {'_id': ObjectId('60392e3656264fee961cae5d'),
#   'date': 20200307,
#   'state': 'MN',
#   'positive': 1,
#   'negative': 48,
#   'hash': 'dff67d839a61d912b7f7b0aa8a8eee5450a0add1',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 49,
#   'totalTestResults': 49,
#   'posNeg': 49,
#   'fips': '27',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 12,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 13},
#  {'_id': ObjectId('60392e3656264fee961cae5e'),
#   'date': 20200307,
#   'state': 'MO',
#   'positive': 0,
#   'hash': '9a6811180ce7cb71ab44738976d76cc4d0c0367c',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 0,
#   'totalTestResults': 0,
#   'posNeg': 0,
#   'fips': '29',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae5f'),
#   'date': 20200307,
#   'state': 'MS',
#   'positive': 0,
#   'hash': '8fd30f9053208bfd268115213ef81816a8d68513',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 0,
#   'totalTestResults': 0,
#   'posNeg': 0,
#   'fips': '28',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae60'),
#   'date': 20200307,
#   'state': 'MT',
#   'positive': 0,
#   'negative': 11,
#   'hash': 'c798a10143524f3b801c3c12385d46f0d5445c45',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 11,
#   'totalTestResults': 11,
#   'posNeg': 11,
#   'fips': '30',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae61'),
#   'date': 20200307,
#   'state': 'NC',
#   'positive': 2,
#   'hash': '430c5790ef495a5f85b57fec34083672077f2925',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 2,
#   'totalTestResults': 2,
#   'posNeg': 2,
#   'fips': '37',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae62'),
#   'date': 20200307,
#   'state': 'ND',
#   'positive': 0,
#   'negative': 0,
#   'hash': 'fd7ee9e623951efec04cf75ce2f3bcadec68ab35',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 0,
#   'totalTestResults': 0,
#   'posNeg': 0,
#   'fips': '38',
#   'deathIncrease': None,
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'positiveIncrease': None,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961cae63'),
#   'date': 20200307,
#   'state': 'NE',
#   'positive': 1,
#   'negative': 17,
#   'pending': 5,
#   'hash': 'f005dd04ec69b52d21ffd219b42d10b897d2ddf8',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 23,
#   'totalTestResults': 18,
#   'posNeg': 18,
#   'fips': '31',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 1},
#  {'_id': ObjectId('60392e3656264fee961cae64'),
#   'date': 20200307,
#   'state': 'NH',
#   'positive': 2,
#   'negative': 20,
#   'pending': 3,
#   'hash': 'c3cf83675171ed0cb3ea76ec42d8087ed0549f2a',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 25,
#   'totalTestResults': 22,
#   'posNeg': 22,
#   'fips': '33',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae65'),
#   'date': 20200307,
#   'state': 'NJ',
#   'positive': 4,
#   'negative': None,
#   'pending': 1,
#   'hash': 'baa3a70b588e2de1d71ef9323e1fd51c2ddd7bf2',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 5,
#   'totalTestResults': 4,
#   'posNeg': 4,
#   'fips': '34',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 3,
#   'totalTestResultsIncrease': 3},
#  {'_id': ObjectId('60392e3656264fee961cae66'),
#   'date': 20200307,
#   'state': 'NM',
#   'positive': 0,
#   'negative': 48,
#   'pending': 0,
#   'hash': 'd4fe05fba86ad47f27ecc0a2843641fc598e7ee2',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 48,
#   'totalTestResults': 48,
#   'posNeg': 48,
#   'fips': '35',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 32,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 32},
#  {'_id': ObjectId('60392e3656264fee961cae67'),
#   'date': 20200307,
#   'state': 'NV',
#   'positive': 1,
#   'negative': 14,
#   'hash': 'ff7e53fb3780e09b6df2422f8b4c69da6e7984d0',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 15,
#   'totalTestResults': 15,
#   'posNeg': 15,
#   'fips': '32',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cae68'),
#   'date': 20200307,
#   'state': 'NY',
#   'positive': 76,
#   'negative': 92,
#   'pending': 236,
#   'hash': '53a82f90b4d4a28a5b06248b1e4c78e9229312dd',
#   'dateChecked': '2020-03-07T21:00:00Z',
#   'total': 404,
#   'totalTestResults': 168,
#   'posNeg': 168,
#   'fips': '36',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 43,
#   'totalTestResultsIncrease': 43},
# ...
#   'death': 1,
#   'hospitalized': None,
#   'total': 99,
#   'totalTestResults': 99,
#   'posNeg': 99,
#   'fips': '20',
#   'deathIncrease': 1,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cacf2'),
#   'date': 20200314,
#   'state': 'KY',
#   'positive': 14,
#   'negative': 139,
#   'hash': '53ea76cd7050bee2da9a57fca2b4538d1926af6d',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 153,
#   'totalTestResults': 153,
#   'posNeg': 153,
#   'fips': '21',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 32,
#   'positiveIncrease': 3,
#   'totalTestResultsIncrease': 35},
#  {'_id': ObjectId('60392e3656264fee961cacf3'),
#   'date': 20200314,
#   'state': 'LA',
#   'positive': 69,
#   'negative': 109,
#   'hash': 'c80c2be31c70d2b05d47fb0b55f9297f827690f7',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 178,
#   'totalTestResults': 178,
#   'posNeg': 178,
#   'fips': '22',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 72,
#   'positiveIncrease': 33,
#   'totalTestResultsIncrease': 105},
#  {'_id': ObjectId('60392e3656264fee961cacf4'),
#   'date': 20200314,
#   'state': 'MA',
#   'positive': 138,
#   'negative': 352,
#   'hash': 'bdba6fc0046699f5419368f4eb93e84eb0f025c5',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 490,
#   'totalTestResults': 490,
#   'posNeg': 490,
#   'fips': '25',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 260,
#   'positiveIncrease': 15,
#   'totalTestResultsIncrease': 275},
#  {'_id': ObjectId('60392e3656264fee961cacf5'),
#   'date': 20200314,
#   'state': 'MD',
#   'positive': 26,
#   'negative': 94,
#   'hash': '8fefdbf242c49256c9711173cc7a195bdfeaf897',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 120,
#   'totalTestResults': 120,
#   'posNeg': 120,
#   'fips': '24',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 9,
#   'totalTestResultsIncrease': 9},
#  {'_id': ObjectId('60392e3656264fee961cacf6'),
#   'date': 20200314,
#   'state': 'ME',
#   'positive': 3,
#   'negative': 91,
#   'pending': 17,
#   'hash': 'f8e0701ef750fd7833940e085f356967698a709e',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 111,
#   'totalTestResults': 94,
#   'posNeg': 94,
#   'fips': '23',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cacf7'),
#   'date': 20200314,
#   'state': 'MI',
#   'positive': 25,
#   'negative': 205,
#   'pending': 26,
#   'hash': '1ef0c5ec35b9fb7fbce11af20dc3982433b1ae1c',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 256,
#   'totalTestResults': 230,
#   'posNeg': 230,
#   'fips': '26',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 72,
#   'positiveIncrease': 9,
#   'totalTestResultsIncrease': 81},
#  {'_id': ObjectId('60392e3656264fee961cacf8'),
#   'date': 20200314,
#   'state': 'MN',
#   'positive': 21,
#   'negative': 847,
#   'hash': '43db9c125581cdb0eaed4688c2bcc3692d524ccd',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 868,
#   'totalTestResults': 868,
#   'posNeg': 868,
#   'fips': '27',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 306,
#   'positiveIncrease': 7,
#   'totalTestResultsIncrease': 313},
#  {'_id': ObjectId('60392e3656264fee961cacf9'),
#   'date': 20200314,
#   'state': 'MO',
#   'positive': 4,
#   'negative': 90,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'hash': '5220c08925c1338bbc1ababb24afaf6558a68b9c',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'death': 0,
#   'hospitalized': None,
#   'total': 94,
#   'totalTestResults': 94,
#   'posNeg': 94,
#   'fips': '29',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 19,
#   'positiveIncrease': 2,
#   'totalTestResultsIncrease': 21},
#  {'_id': ObjectId('60392e3656264fee961cacfa'),
#   'date': 20200314,
#   'state': 'MS',
#   'positive': 6,
#   'negative': 84,
#   'hash': '262146bdcf966d7bd2b95df77b8c19d904242248',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 90,
#   'totalTestResults': 90,
#   'posNeg': 90,
#   'fips': '28',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 43,
#   'positiveIncrease': 2,
#   'totalTestResultsIncrease': 45},
#  {'_id': ObjectId('60392e3656264fee961cacfb'),
#   'date': 20200314,
#   'state': 'MT',
#   'positive': 5,
#   'negative': 103,
#   'hash': '3b3767d29a7f2c8246d957b64ab51b460e66230c',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 108,
#   'totalTestResults': 108,
#   'posNeg': 108,
#   'fips': '30',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 48,
#   'positiveIncrease': 4,
#   'totalTestResultsIncrease': 52},
#  {'_id': ObjectId('60392e3656264fee961cacfc'),
#   'date': 20200314,
#   'state': 'NC',
#   'positive': 23,
#   'negative': 137,
#   'hash': '1097b4e88ff28fd47bd79effc50736bcc4f98d4d',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 160,
#   'totalTestResults': 160,
#   'posNeg': 160,
#   'fips': '37',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 51,
#   'positiveIncrease': 8,
#   'totalTestResultsIncrease': 59},
#  {'_id': ObjectId('60392e3656264fee961cacfd'),
#   'date': 20200314,
#   'state': 'ND',
#   'positive': 1,
#   'negative': 54,
#   'pending': 14,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'hash': 'a52a443da4b61469c6be7d12ad2fe848c421dd0f',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'death': 0,
#   'hospitalized': None,
#   'total': 69,
#   'totalTestResults': 55,
#   'posNeg': 55,
#   'fips': '38',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 15,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 15},
#  {'_id': ObjectId('60392e3656264fee961cacfe'),
#   'date': 20200314,
#   'state': 'NE',
#   'positive': 14,
#   'negative': 80,
#   'pending': 33,
#   'hash': '936f44463ab4c62d7cf30fc400ef265c45f8b3f5',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 127,
#   'totalTestResults': 94,
#   'posNeg': 94,
#   'fips': '31',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 1},
#  {'_id': ObjectId('60392e3656264fee961cacff'),
#   'date': 20200314,
#   'state': 'NH',
#   'positive': 7,
#   'negative': 212,
#   'pending': 31,
#   'hash': '8df5e37a5d8dabbb6fb2821a99d3d0d90b27fc85',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 250,
#   'totalTestResults': 219,
#   'posNeg': 219,
#   'fips': '33',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 118,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 119},
#  {'_id': ObjectId('60392e3656264fee961cad00'),
#   'date': 20200314,
#   'state': 'NJ',
#   'positive': 50,
#   'negative': 97,
#   'pending': 80,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'hash': '0b8634c5fd4e1160dde841c792bf7c6fc9315232',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'death': 1,
#   'hospitalized': None,
#   'total': 227,
#   'totalTestResults': 147,
#   'posNeg': 147,
#   'fips': '34',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cad01'),
#   'date': 20200314,
#   'state': 'NM',
#   'positive': 10,
#   'negative': 237,
#   'hash': '0085a52176e881bb6ad037e0c30af4f74d9489f9',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 247,
#   'totalTestResults': 247,
#   'posNeg': 247,
#   'fips': '35',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 47,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 47},
#  {'_id': ObjectId('60392e3656264fee961cad02'),
#   'date': 20200314,
#   'state': 'NV',
#   'positive': 20,
#   'negative': 168,
#   'hash': '2e60e44122a1faf4a4351249cef4569aeb6b4a89',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 188,
#   'totalTestResults': 188,
#   'posNeg': 188,
#   'fips': '32',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 9,
#   'totalTestResultsIncrease': 9},
#  {'_id': ObjectId('60392e3656264fee961cad03'),
#   'date': 20200314,
#   'state': 'NY',
#   'positive': 524,
#   'negative': 2779,
#   'hash': 'f28c39ca671c26d022ff2556494ad8767765eb93',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 3303,
#   'totalTestResults': 3303,
#   'posNeg': 3303,
#   'fips': '36',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 103,
#   'totalTestResultsIncrease': 103},
#  {'_id': ObjectId('60392e3656264fee961cad04'),
#   'date': 20200314,
#   'state': 'OH',
#   'positive': 13,
#   'negative': 50,
#   'pending': 159,
#   'hash': 'fc63d6218734893ad458fb97af8018f3a1ec1ad5',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 222,
#   'totalTestResults': 63,
#   'posNeg': 63,
#   'fips': '39',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cad05'),
#   'date': 20200314,
#   'state': 'OK',
#   'positive': 4,
#   'negative': 36,
#   'pending': 37,
#   'hash': 'c73b103132566a7e2d3c71510adc6def73b88940',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 77,
#   'totalTestResults': 40,
#   'posNeg': 40,
#   'fips': '40',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 1},
#  {'_id': ObjectId('60392e3656264fee961cad06'),
#   'date': 20200314,
#   'state': 'OR',
#   'positive': 30,
#   'negative': 337,
#   'pending': 157,
#   'hash': '1400911ca9d80be2f8e342c113a1df4d70338602',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 524,
#   'totalTestResults': 367,
#   'posNeg': 367,
#   'fips': '41',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cad07'),
#   'date': 20200314,
#   'state': 'PA',
#   'positive': 47,
#   'negative': 205,
#   'pending': 150,
#   'hash': 'd18f94522023cea299270dcc1602530f2ddc0dc4',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 402,
#   'totalTestResults': 252,
#   'posNeg': 252,
#   'fips': '42',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 65,
#   'positiveIncrease': 14,
#   'totalTestResultsIncrease': 79},
#  {'_id': ObjectId('60392e3656264fee961cad08'),
#   'date': 20200314,
#   'state': 'RI',
#   'positive': 20,
#   'negative': 198,
#   'pending': 57,
#   'hash': '398dbebda7a13f625f8978b5e493f80fa0c06bc4',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 275,
#   'totalTestResults': 218,
#   'posNeg': 218,
#   'fips': '44',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 56,
#   'positiveIncrease': 6,
#   'totalTestResultsIncrease': 62},
#  {'_id': ObjectId('60392e3656264fee961cad09'),
#   'date': 20200314,
#   'state': 'SC',
#   'positive': 13,
#   'negative': 110,
#   'hash': 'f59023a910249b3d8b3511ae10d8f11517a1c519',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 123,
#   'totalTestResults': 123,
#   'posNeg': 123,
#   'fips': '45',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 35,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 36},
#  {'_id': ObjectId('60392e3656264fee961cad0a'),
#   'date': 20200314,
#   'state': 'SD',
#   'positive': 9,
#   'negative': 182,
#   'pending': 3,
#   'hash': 'df4f632f3d3f47fd86232363e123ffd6096af646',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 194,
#   'totalTestResults': 191,
#   'posNeg': 191,
#   'fips': '46',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 109,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 109},
#  {'_id': ObjectId('60392e3656264fee961cad0b'),
#   'date': 20200314,
#   'state': 'TN',
#   'positive': 32,
#   'negative': 130,
#   'hash': '6becf2091344bee8d3a7f0a0a437ccf76ed9dd53',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 162,
#   'totalTestResults': 162,
#   'posNeg': 162,
#   'fips': '47',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 14,
#   'positiveIncrease': 6,
#   'totalTestResultsIncrease': 20},
#  {'_id': ObjectId('60392e3656264fee961cad0c'),
#   'date': 20200314,
#   'state': 'TX',
#   'positive': 51,
#   'hash': '8a47a6e610ae58718993de453b89aa3908c67fbd',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 51,
#   'totalTestResults': 51,
#   'posNeg': 51,
#   'fips': '48',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 12,
#   'totalTestResultsIncrease': 12},
#  {'_id': ObjectId('60392e3656264fee961cad0d'),
#   'date': 20200314,
#   'state': 'UT',
#   'positive': 6,
#   'negative': 131,
#   'hash': '577b43eb324c0ae69322cc15f477ca37d5daf36b',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 137,
#   'totalTestResults': 137,
#   'posNeg': 137,
#   'fips': '49',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cad0e'),
#   'date': 20200314,
#   'state': 'VA',
#   'positive': 30,
#   'negative': 117,
#   'hash': '33f505467e5a143bd0ecda4d5622091a48ad3d2e',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 147,
#   'totalTestResults': 147,
#   'posNeg': 147,
#   'fips': '51',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cad0f'),
#   'date': 20200314,
#   'state': 'VT',
#   'positive': 4,
#   'negative': 227,
#   'hash': '570d73d25152c4e93987f89a83b40ff5480a7682',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 231,
#   'totalTestResults': 231,
#   'posNeg': 231,
#   'fips': '50',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 85,
#   'positiveIncrease': 2,
#   'totalTestResultsIncrease': 87},
#  {'_id': ObjectId('60392e3656264fee961cad10'),
#   'date': 20200314,
#   'state': 'WA',
#   'positive': 568,
#   'negative': 6001,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'hash': 'd0c542a7903d9d53eee47064cd36f4618727252d',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'death': 37,
#   'hospitalized': None,
#   'total': 6569,
#   'totalTestResults': 6569,
#   'posNeg': 6569,
#   'fips': '53',
#   'deathIncrease': 6,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 1651,
#   'positiveIncrease': 111,
#   'totalTestResultsIncrease': 1762},
#  {'_id': ObjectId('60392e3656264fee961cad11'),
#   'date': 20200314,
#   'state': 'WI',
#   'positive': 19,
#   'negative': 169,
#   'hash': '8f1ed69b1d5723cbd5b18d1ec332fa4f83bde08a',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 188,
#   'totalTestResults': 188,
#   'posNeg': 188,
#   'fips': '55',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961cad12'),
#   'date': 20200314,
#   'state': 'WV',
#   'positive': 0,
#   'negative': 26,
#   'pending': 5,
#   'hash': '7e27957cf04398b64db2982ccd580fd5455ffebb',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 31,
#   'totalTestResults': 26,
#   'posNeg': 26,
#   'fips': '54',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 9,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 9},
#  {'_id': ObjectId('60392e3656264fee961cad13'),
#   'date': 20200314,
#   'state': 'WY',
#   'positive': 2,
#   'hash': '00d1959cf22a0162be10edb9d849b320e1db37e7',
#   'dateChecked': '2020-03-14T20:00:00Z',
#   'total': 2,
#   'totalTestResults': 2,
#   'posNeg': 2,
#   'fips': '56',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 1,
#   'totalTestResultsIncrease': 1}]

# %%
# Good job!
# Don't forget to push with ./submit.sh
