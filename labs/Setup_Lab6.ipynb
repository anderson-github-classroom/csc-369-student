# %% [markdown]
# # Setup of Lab 6

# %%
import pymongo

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
db = client["csc-369"]

col = db["daily"]

# %%
import json
data = json.loads(open('../data/daily.json').read())

# %%
x = col.insert_many(data)

# %%
x

# %%
import pprint
pprint.pprint(list(col.find()))
# Out:
# [{'_id': ObjectId('60392e3656264fee961ca816'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 6,
#   'deathIncrease': 1,
#   'fips': '02',
#   'hash': '661d7b0f627847a2dceb5d70d4e9260965031cc2',
#   'hospitalized': 20,
#   'hospitalizedCumulative': 20,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 4,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 6099,
#   'negativeIncrease': 230,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 6284,
#   'positive': 185,
#   'positiveIncrease': 14,
#   'recovered': None,
#   'state': 'AK',
#   'total': 6284,
#   'totalTestResults': 6284,
#   'totalTestResultsIncrease': 244},
#  {'_id': ObjectId('60392e3656264fee961ca817'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 45,
#   'deathIncrease': 2,
#   'fips': '01',
#   'hash': '3f2c1f28926eeadf623d04aeb3716d29c5394d3c',
#   'hospitalized': 231,
#   'hospitalizedCumulative': 231,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 19,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 11282,
#   'negativeIncrease': 2009,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 13078,
#   'positive': 1796,
#   'positiveIncrease': 216,
#   'recovered': None,
#   'state': 'AL',
#   'total': 13078,
#   'totalTestResults': 13078,
#   'totalTestResultsIncrease': 2225},
#  {'_id': ObjectId('60392e3656264fee961ca818'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 16,
#   'deathIncrease': 2,
#   'fips': '05',
#   'hash': '3796ddde6259ef7ec36ee05d5793202c57b91aba',
#   'hospitalized': 130,
#   'hospitalizedCumulative': 130,
#   'hospitalizedCurrently': 67,
#   'hospitalizedIncrease': 130,
#   'inIcuCumulative': 43,
#   'inIcuCurrently': None,
#   'negative': 10412,
#   'negativeIncrease': 785,
#   'onVentilatorCumulative': 39,
#   'onVentilatorCurrently': 27,
#   'pending': None,
#   'posNeg': 11242,
#   'positive': 830,
#   'positiveIncrease': 87,
#   'recovered': 97,
#   'state': 'AR',
#   'total': 11242,
#   'totalTestResults': 11242,
#   'totalTestResultsIncrease': 872},
#  {'_id': ObjectId('60392e3656264fee961ca819'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 0,
#   'deathIncrease': 0,
#   'fips': '60',
#   'hash': '10c63821a9227a401ec400c530ba3d1cfa95fe1f',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 20,
#   'negativeIncrease': 0,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 6,
#   'posNeg': 20,
#   'positive': 0,
#   'positiveIncrease': 0,
#   'recovered': None,
#   'state': 'AS',
#   'total': 26,
#   'totalTestResults': 20,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961ca81a'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 64,
#   'deathIncrease': 12,
#   'fips': '04',
#   'hash': 'a706720cd8807eb275a1c60f65cb7fe93b622365',
#   'hospitalized': 310,
#   'hospitalizedCumulative': 310,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 13,
#   'inIcuCumulative': 108,
#   'inIcuCurrently': None,
#   'negative': 25141,
#   'negativeIncrease': 0,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 27410,
#   'positive': 2269,
#   'positiveIncrease': 250,
#   'recovered': None,
#   'state': 'AZ',
#   'total': 27410,
#   'totalTestResults': 27410,
#   'totalTestResultsIncrease': 250},
#  {'_id': ObjectId('60392e3656264fee961ca81b'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 319,
#   'deathIncrease': 43,
#   'fips': '06',
#   'hash': 'b16da92c388833be7769869d9eaf221dabbd9b20',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 2398,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': 1040,
#   'negative': 103095,
#   'negativeIncrease': 1421,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 15000,
#   'posNeg': 116533,
#   'positive': 13438,
#   'positiveIncrease': 1412,
#   'recovered': None,
#   'state': 'CA',
#   'total': 131533,
#   'totalTestResults': 116533,
#   'totalTestResultsIncrease': 2833},
#  {'_id': ObjectId('60392e3656264fee961ca81c'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 126,
#   'deathIncrease': 15,
#   'fips': '08',
#   'hash': 'fcc0e0c27878a3bcebc317c1b7a832e38964ff16',
#   'hospitalized': 875,
#   'hospitalizedCumulative': 875,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 52,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 19335,
#   'negativeIncrease': 1437,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 23900,
#   'positive': 4565,
#   'positiveIncrease': 392,
#   'recovered': None,
#   'state': 'CO',
#   'total': 23900,
#   'totalTestResults': 23900,
#   'totalTestResultsIncrease': 1829},
#  {'_id': ObjectId('60392e3656264fee961ca81d'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 189,
#   'deathIncrease': 24,
#   'fips': '09',
#   'hash': '1e92cd4c9468e9740d884cae46aa7fa1d8ad63e8',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 1142,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 17595,
#   'negativeIncrease': 842,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 23270,
#   'positive': 5675,
#   'positiveIncrease': 399,
#   'recovered': None,
#   'state': 'CT',
#   'total': 23270,
#   'totalTestResults': 23270,
#   'totalTestResultsIncrease': 1241},
#  {'_id': ObjectId('60392e3656264fee961ca81e'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 22,
#   'deathIncrease': 1,
#   'fips': '11',
#   'hash': '492481c558e3cbdafc4289535e3c9f10603f6f0a',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 5836,
#   'negativeIncrease': 300,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 6834,
#   'positive': 998,
#   'positiveIncrease': 96,
#   'recovered': 258,
#   'state': 'DC',
#   'total': 6834,
#   'totalTestResults': 6834,
#   'totalTestResultsIncrease': 396},
#  {'_id': ObjectId('60392e3656264fee961ca81f'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 14,
#   'deathIncrease': 0,
#   'fips': '10',
#   'hash': '4cfd22e6ea296fbca4f9ce0ea79a4b1b69a56eef',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 101,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 6321,
#   'negativeIncrease': 447,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 6994,
#   'positive': 673,
#   'positiveIncrease': 80,
#   'recovered': 71,
#   'state': 'DE',
#   'total': 6994,
#   'totalTestResults': 6994,
#   'totalTestResultsIncrease': 527},
#  {'_id': ObjectId('60392e3656264fee961ca820'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 218,
#   'deathIncrease': 27,
#   'fips': '12',
#   'hash': 'a93e5474b39c59e992996dd7ffc9f886446156c1',
#   'hospitalized': 1572,
#   'hospitalizedCumulative': 1572,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 110,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 101253,
#   'negativeIncrease': 10297,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 1129,
#   'posNeg': 113404,
#   'positive': 12151,
#   'positiveIncrease': 1040,
#   'recovered': None,
#   'state': 'FL',
#   'total': 114533,
#   'totalTestResults': 113404,
#   'totalTestResultsIncrease': 11337},
#  {'_id': ObjectId('60392e3656264fee961ca821'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 211,
#   'deathIncrease': 10,
#   'fips': '13',
#   'hash': 'd574a55e0cbdbd204007cc62e7d7da3ff1222c38',
#   'hospitalized': 1283,
#   'hospitalizedCumulative': 1283,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 44,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 21185,
#   'negativeIncrease': 1051,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 27832,
#   'positive': 6647,
#   'positiveIncrease': 487,
#   'recovered': None,
#   'state': 'GA',
#   'total': 27832,
#   'totalTestResults': 27832,
#   'totalTestResultsIncrease': 1538},
#  {'_id': ObjectId('60392e3656264fee961ca822'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 4,
#   'deathIncrease': 0,
#   'fips': '66',
#   'hash': '4447d3835bcee7be41ca94379c5f3ac7d2c739e2',
#   'hospitalized': 31,
#   'hospitalizedCumulative': 31,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': 2,
#   'inIcuCurrently': None,
#   'negative': 493,
#   'negativeIncrease': 21,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 605,
#   'positive': 112,
#   'positiveIncrease': 19,
#   'recovered': 23,
#   'state': 'GU',
#   'total': 605,
#   'totalTestResults': 605,
#   'totalTestResultsIncrease': 40},
#  {'_id': ObjectId('60392e3656264fee961ca823'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 4,
#   'deathIncrease': 1,
#   'fips': '15',
#   'hash': '77397e6e6161c484fd9fd351a7a97f2504e3ef04',
#   'hospitalized': 19,
#   'hospitalizedCumulative': 19,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 1,
#   'inIcuCumulative': 6,
#   'inIcuCurrently': None,
#   'negative': 12604,
#   'negativeIncrease': 645,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 12955,
#   'positive': 351,
#   'positiveIncrease': 32,
#   'recovered': 82,
#   'state': 'HI',
#   'total': 12955,
#   'totalTestResults': 12955,
#   'totalTestResultsIncrease': 677},
#  {'_id': ObjectId('60392e3656264fee961ca824'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 22,
#   'deathIncrease': 8,
#   'fips': '19',
#   'hash': 'ddab7f4fb076f0753905ad90cf58ce0af0c83e02',
#   'hospitalized': 165,
#   'hospitalizedCumulative': 165,
#   'hospitalizedCurrently': 91,
#   'hospitalizedIncrease': 12,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 9973,
#   'negativeIncrease': 519,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 10841,
#   'positive': 868,
#   'positiveIncrease': 82,
#   'recovered': 188,
#   'state': 'IA',
#   'total': 10841,
#   'totalTestResults': 10841,
#   'totalTestResultsIncrease': 601},
#  {'_id': ObjectId('60392e3656264fee961ca825'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 10,
#   'deathIncrease': 0,
#   'fips': '16',
#   'hash': '181bae20b5e5d41e5e68a4ac2fbbec0ead002f93',
#   'hospitalized': 66,
#   'hospitalizedCumulative': 66,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 4,
#   'inIcuCumulative': 11,
#   'inIcuCurrently': None,
#   'negative': 9184,
#   'negativeIncrease': 1327,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 10261,
#   'positive': 1077,
#   'positiveIncrease': 64,
#   'recovered': None,
#   'state': 'ID',
#   'total': 10261,
#   'totalTestResults': 10261,
#   'totalTestResultsIncrease': 1391},
#  {'_id': ObjectId('60392e3656264fee961ca826'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 274,
#   'deathIncrease': 31,
#   'fips': '17',
#   'hash': 'd76333be7d0f922df9b8b422717d922c15da272f',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 47727,
#   'negativeIncrease': 4503,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 58983,
#   'positive': 11256,
#   'positiveIncrease': 899,
#   'recovered': None,
#   'state': 'IL',
#   'total': 58983,
#   'totalTestResults': 58983,
#   'totalTestResultsIncrease': 5402},
#  {'_id': ObjectId('60392e3656264fee961ca827'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 127,
#   'deathIncrease': 11,
#   'fips': '18',
#   'hash': 'f93680f2440d0a80612808fcc143041ba9cb2558',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 18241,
#   'negativeIncrease': 2394,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 22652,
#   'positive': 4411,
#   'positiveIncrease': 458,
#   'recovered': None,
#   'state': 'IN',
#   'total': 22652,
#   'totalTestResults': 22652,
#   'totalTestResultsIncrease': 2852},
#  {'_id': ObjectId('60392e3656264fee961ca828'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 22,
#   'deathIncrease': 1,
#   'fips': '20',
#   'hash': 'dae86135f02c394b72b0ae420bb652e62b1475ff',
#   'hospitalized': 183,
#   'hospitalizedCumulative': 183,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 11,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 7476,
#   'negativeIncrease': 596,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 8223,
#   'positive': 747,
#   'positiveIncrease': 49,
#   'recovered': None,
#   'state': 'KS',
#   'total': 8223,
#   'totalTestResults': 8223,
#   'totalTestResultsIncrease': 645},
#  {'_id': ObjectId('60392e3656264fee961ca829'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 40,
#   'deathIncrease': 3,
#   'fips': '21',
#   'hash': 'b04b342a420aa4f3ebcda1e367731dcabb035fe9',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 15746,
#   'negativeIncrease': 1005,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 16663,
#   'positive': 917,
#   'positiveIncrease': 86,
#   'recovered': None,
#   'state': 'KY',
#   'total': 16663,
#   'totalTestResults': 16663,
#   'totalTestResultsIncrease': 1091},
#  {'_id': ObjectId('60392e3656264fee961ca82a'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 477,
#   'deathIncrease': 68,
#   'fips': '22',
#   'hash': '54b0aaaa06fce89fecccf2fd6ce9501b9190d7b5',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 1803,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 47315,
#   'negativeIncrease': 1313,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': 561,
#   'pending': None,
#   'posNeg': 60325,
#   'positive': 13010,
#   'positiveIncrease': 514,
#   'recovered': None,
#   'state': 'LA',
#   'total': 60325,
#   'totalTestResults': 60325,
#   'totalTestResultsIncrease': 1827},
#  {'_id': ObjectId('60392e3656264fee961ca82b'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 231,
#   'deathIncrease': 15,
#   'fips': '25',
#   'hash': 'd25b1917417ab57d0ef9e85c85c1a5cca2cc7e36',
#   'hospitalized': 1145,
#   'hospitalizedCumulative': 1145,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 77,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 59437,
#   'negativeIncrease': 2373,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 71937,
#   'positive': 12500,
#   'positiveIncrease': 764,
#   'recovered': None,
#   'state': 'MA',
#   'total': 71937,
#   'totalTestResults': 71937,
#   'totalTestResultsIncrease': 3137},
#  {'_id': ObjectId('60392e3656264fee961ca82c'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 67,
#   'deathIncrease': 14,
#   'fips': '24',
#   'hash': 'cac549d0b74daccf3ab34404fc5dd3812b44bbff',
#   'hospitalized': 936,
#   'hospitalizedCumulative': 936,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 115,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 24728,
#   'negativeIncrease': 2243,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 28337,
#   'positive': 3609,
#   'positiveIncrease': 484,
#   'recovered': 159,
#   'state': 'MD',
#   'total': 28337,
#   'totalTestResults': 28337,
#   'totalTestResultsIncrease': 2727},
#  {'_id': ObjectId('60392e3656264fee961ca82d'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 10,
#   'deathIncrease': 0,
#   'fips': '23',
#   'hash': '251d971acb2a0763de6451631e1f79284d54e187',
#   'hospitalized': 86,
#   'hospitalizedCumulative': 86,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 3,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 6088,
#   'negativeIncrease': 0,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 6558,
#   'positive': 470,
#   'positiveIncrease': 14,
#   'recovered': 156,
#   'state': 'ME',
#   'total': 6558,
#   'totalTestResults': 6558,
#   'totalTestResultsIncrease': 14},
#  {'_id': ObjectId('60392e3656264fee961ca82e'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 617,
#   'deathIncrease': 77,
#   'fips': '26',
#   'hash': 'f6a4d71ca2c195d3a7577e9a108597c378a88d53',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 30030,
#   'negativeIncrease': 18137,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 45748,
#   'positive': 15718,
#   'positiveIncrease': 1493,
#   'recovered': None,
#   'state': 'MI',
#   'total': 45748,
#   'totalTestResults': 45748,
#   'totalTestResultsIncrease': 19630},
#  {'_id': ObjectId('60392e3656264fee961ca82f'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 29,
#   'deathIncrease': 5,
#   'fips': '27',
#   'hash': 'c7075ad182d0178bcc22aab78d7cd3495cca7d7d',
#   'hospitalized': 202,
#   'hospitalizedCumulative': 202,
#   'hospitalizedCurrently': 106,
#   'hospitalizedIncrease': 22,
#   'inIcuCumulative': 77,
#   'inIcuCurrently': 48,
#   'negative': 25842,
#   'negativeIncrease': 1284,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 26777,
#   'positive': 935,
#   'positiveIncrease': 70,
#   'recovered': 451,
#   'state': 'MN',
#   'total': 26777,
#   'totalTestResults': 26777,
#   'totalTestResultsIncrease': 1354},
#  {'_id': ObjectId('60392e3656264fee961ca830'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 34,
#   'deathIncrease': 10,
#   'fips': '29',
#   'hash': '434ac4b9d0cbd2143af60703aa3aedc944b8ed77',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 424,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 24882,
#   'negativeIncrease': 2268,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 27249,
#   'positive': 2367,
#   'positiveIncrease': 76,
#   'recovered': None,
#   'state': 'MO',
#   'total': 27249,
#   'totalTestResults': 27249,
#   'totalTestResultsIncrease': 2344},
#  {'_id': ObjectId('60392e3656264fee961ca831'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 1,
#   'deathIncrease': 0,
#   'fips': '69',
#   'hash': '2dfb8a2e3962fb5328cb829dac324abbea5ea5c2',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 13,
#   'negativeIncrease': 0,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 10,
#   'posNeg': 21,
#   'positive': 8,
#   'positiveIncrease': 0,
#   'recovered': None,
#   'state': 'MP',
#   'total': 31,
#   'totalTestResults': 21,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961ca832'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 43,
#   'deathIncrease': 8,
#   'fips': '28',
#   'hash': '7e075b052224457cec693d4aa2f7c8c5b76962d3',
#   'hospitalized': 475,
#   'hospitalizedCumulative': 475,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 39,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 5580,
#   'negativeIncrease': 447,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 7218,
#   'positive': 1638,
#   'positiveIncrease': 183,
#   'recovered': None,
#   'state': 'MS',
#   'total': 7218,
#   'totalTestResults': 7218,
#   'totalTestResultsIncrease': 630},
#  {'_id': ObjectId('60392e3656264fee961ca833'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 6,
#   'deathIncrease': 1,
#   'fips': '30',
#   'hash': 'df75d2ad9e7baae0b40fddec219b81def7584a74',
#   'hospitalized': 24,
#   'hospitalizedCumulative': 24,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 6317,
#   'negativeIncrease': 405,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 6603,
#   'positive': 286,
#   'positiveIncrease': 21,
#   'recovered': None,
#   'state': 'MT',
#   'total': 6603,
#   'totalTestResults': 6603,
#   'totalTestResultsIncrease': 426},
#  {'_id': ObjectId('60392e3656264fee961ca834'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 31,
#   'deathIncrease': 7,
#   'fips': '37',
#   'hash': '4d5b54fff38c79c5d34358a4fc1ecd201692b759',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 261,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 37460,
#   'negativeIncrease': 1089,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 40045,
#   'positive': 2585,
#   'positiveIncrease': 183,
#   'recovered': None,
#   'state': 'NC',
#   'total': 40045,
#   'totalTestResults': 40045,
#   'totalTestResultsIncrease': 1272},
#  {'_id': ObjectId('60392e3656264fee961ca835'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 3,
#   'deathIncrease': 0,
#   'fips': '38',
#   'hash': '6a4b61d1260f55fee4335342942c41cf34e82bab',
#   'hospitalized': 31,
#   'hospitalizedCumulative': 31,
#   'hospitalizedCurrently': 20,
#   'hospitalizedIncrease': 1,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 6580,
#   'negativeIncrease': 559,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 6787,
#   'positive': 207,
#   'positiveIncrease': 21,
#   'recovered': 63,
#   'state': 'ND',
#   'total': 6787,
#   'totalTestResults': 6787,
#   'totalTestResultsIncrease': 580},
#  {'_id': ObjectId('60392e3656264fee961ca836'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 8,
#   'deathIncrease': 2,
#   'fips': '31',
#   'hash': '6249d274e5c51fbff387c37b8d9ef435910c9a47',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 5558,
#   'negativeIncrease': 500,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 12,
#   'posNeg': 5921,
#   'positive': 363,
#   'positiveIncrease': 42,
#   'recovered': None,
#   'state': 'NE',
#   'total': 5933,
#   'totalTestResults': 5921,
#   'totalTestResultsIncrease': 542},
#  {'_id': ObjectId('60392e3656264fee961ca837'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 9,
#   'deathIncrease': 2,
#   'fips': '33',
#   'hash': 'd5c04e13103086262e57257b6f168cab23603a0b',
#   'hospitalized': 86,
#   'hospitalizedCumulative': 86,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 6,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 7411,
#   'negativeIncrease': 446,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 93,
#   'posNeg': 8032,
#   'positive': 621,
#   'positiveIncrease': 81,
#   'recovered': 146,
#   'state': 'NH',
#   'total': 8125,
#   'totalTestResults': 8032,
#   'totalTestResultsIncrease': 527},
#  {'_id': ObjectId('60392e3656264fee961ca838'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 917,
#   'deathIncrease': 71,
#   'fips': '34',
#   'hash': 'c470de49445362b0bb28cf0290d270d2969e49bf',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 44661,
#   'negativeIncrease': 3429,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 82166,
#   'positive': 37505,
#   'positiveIncrease': 3381,
#   'recovered': None,
#   'state': 'NJ',
#   'total': 82166,
#   'totalTestResults': 82166,
#   'totalTestResultsIncrease': 6810},
#  {'_id': ObjectId('60392e3656264fee961ca839'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 11,
#   'deathIncrease': 1,
#   'fips': '35',
#   'hash': '63f30ca9eb0ba350762c320c91a6b9c3ee657611',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 37,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 16285,
#   'negativeIncrease': 1148,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': 18,
#   'pending': None,
#   'posNeg': 16828,
#   'positive': 543,
#   'positiveIncrease': 48,
#   'recovered': 54,
#   'state': 'NM',
#   'total': 16828,
#   'totalTestResults': 16828,
#   'totalTestResultsIncrease': 1196},
#  {'_id': ObjectId('60392e3656264fee961ca83a'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 46,
#   'deathIncrease': 0,
#   'fips': '32',
#   'hash': 'eed461ec57cf1fb0231459c7950a45d60e402fc7',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 14995,
#   'negativeIncrease': 574,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 16831,
#   'positive': 1836,
#   'positiveIncrease': 94,
#   'recovered': None,
#   'state': 'NV',
#   'total': 16831,
#   'totalTestResults': 16831,
#   'totalTestResultsIncrease': 668},
#  {'_id': ObjectId('60392e3656264fee961ca83b'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 4159,
#   'deathIncrease': 594,
#   'fips': '36',
#   'hash': '58a99b83c7368e224acff5ea100e3692a0b8fa75',
#   'hospitalized': 28092,
#   'hospitalizedCumulative': 28092,
#   'hospitalizedCurrently': 16479,
#   'hospitalizedIncrease': 1709,
#   'inIcuCumulative': None,
#   'inIcuCurrently': 4376,
#   'negative': 180249,
#   'negativeIncrease': 10332,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 302280,
#   'positive': 122031,
#   'positiveIncrease': 8327,
#   'recovered': 12187,
#   'state': 'NY',
#   'total': 302280,
#   'totalTestResults': 302280,
#   'totalTestResultsIncrease': 18659},
#  {'_id': ObjectId('60392e3656264fee961ca83c'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 119,
#   'deathIncrease': 17,
#   'fips': '39',
#   'hash': 'e5ae03b405f85f1d28b2ebb497d115720b0a273c',
#   'hospitalized': 1104,
#   'hospitalizedCumulative': 1104,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 98,
#   'inIcuCumulative': 346,
#   'inIcuCurrently': None,
#   'negative': 39713,
#   'negativeIncrease': 1581,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 43756,
#   'positive': 4043,
#   'positiveIncrease': 304,
#   'recovered': None,
#   'state': 'OH',
#   'total': 43756,
#   'totalTestResults': 43756,
#   'totalTestResultsIncrease': 1885},
#  {'_id': ObjectId('60392e3656264fee961ca83d'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 46,
#   'deathIncrease': 4,
#   'fips': '40',
#   'hash': '6533cee27cd3fff7678c17b003d7f79151d505c6',
#   'hospitalized': 330,
#   'hospitalizedCumulative': 330,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 14,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 1401,
#   'negativeIncrease': 39,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 2653,
#   'positive': 1252,
#   'positiveIncrease': 93,
#   'recovered': None,
#   'state': 'OK',
#   'total': 2653,
#   'totalTestResults': 2653,
#   'totalTestResultsIncrease': 132},
#  {'_id': ObjectId('60392e3656264fee961ca83e'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 26,
#   'deathIncrease': 4,
#   'fips': '41',
#   'hash': 'ecb16bafd0099d524e37fdf1d1a7936bdd699d31',
#   'hospitalized': 239,
#   'hospitalizedCumulative': 239,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 35,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 17926,
#   'negativeIncrease': 1391,
#   'onVentilatorCumulative': 40,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 18925,
#   'positive': 999,
#   'positiveIncrease': 100,
#   'recovered': None,
#   'state': 'OR',
#   'total': 18925,
#   'totalTestResults': 18925,
#   'totalTestResultsIncrease': 1491},
#  {'_id': ObjectId('60392e3656264fee961ca83f'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 150,
#   'deathIncrease': 14,
#   'fips': '42',
#   'hash': '37345694c2105b11def51fd454c4a6757b9e3189',
#   'hospitalized': 1072,
#   'hospitalizedCumulative': 1072,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 68,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 66261,
#   'negativeIncrease': 6248,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 77771,
#   'positive': 11510,
#   'positiveIncrease': 1493,
#   'recovered': None,
#   'state': 'PA',
#   'total': 77771,
#   'totalTestResults': 77771,
#   'totalTestResultsIncrease': 7741},
#  {'_id': ObjectId('60392e3656264fee961ca840'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 20,
#   'deathIncrease': 2,
#   'fips': '72',
#   'hash': '1573ba924ae71c4ae8290b22456399487d9a034b',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 3073,
#   'negativeIncrease': 1008,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 1039,
#   'posNeg': 3548,
#   'positive': 475,
#   'positiveIncrease': 23,
#   'recovered': None,
#   'state': 'PR',
#   'total': 4587,
#   'totalTestResults': 3548,
#   'totalTestResultsIncrease': 1031},
#  {'_id': ObjectId('60392e3656264fee961ca841'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 25,
#   'deathIncrease': 8,
#   'fips': '44',
#   'hash': 'ca3d51fbf6c0fe5c93688b1c7624ce330bebfd6b',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 103,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': 33,
#   'negative': 7181,
#   'negativeIncrease': 1597,
#   'onVentilatorCumulative': 6,
#   'onVentilatorCurrently': 6,
#   'pending': None,
#   'posNeg': 8103,
#   'positive': 922,
#   'positiveIncrease': 116,
#   'recovered': 35,
#   'state': 'RI',
#   'total': 8103,
#   'totalTestResults': 8103,
#   'totalTestResultsIncrease': 1713},
#  {'_id': ObjectId('60392e3656264fee961ca842'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 44,
#   'deathIncrease': 4,
#   'fips': '45',
#   'hash': 'ccdff6113258b5f27c5731a18b0b0b1a1839e358',
#   'hospitalized': 241,
#   'hospitalizedCumulative': 241,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 16927,
#   'negativeIncrease': 530,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 18976,
#   'positive': 2049,
#   'positiveIncrease': 132,
#   'recovered': None,
#   'state': 'SC',
#   'total': 18976,
#   'totalTestResults': 18976,
#   'totalTestResultsIncrease': 662},
#  {'_id': ObjectId('60392e3656264fee961ca843'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 2,
#   'deathIncrease': 0,
#   'fips': '46',
#   'hash': '95a0098886125c0b34f0de459993844962e75bd4',
#   'hospitalized': 22,
#   'hospitalizedCumulative': 22,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 3,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 5353,
#   'negativeIncrease': 341,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 5593,
#   'positive': 240,
#   'positiveIncrease': 28,
#   'recovered': 84,
#   'state': 'SD',
#   'total': 5593,
#   'totalTestResults': 5593,
#   'totalTestResultsIncrease': 369},
#  {'_id': ObjectId('60392e3656264fee961ca844'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 44,
#   'deathIncrease': 1,
#   'fips': '47',
#   'hash': '5a155ea45dcb7ba75630d696556e3c0ed525d402',
#   'hospitalized': 328,
#   'hospitalizedCumulative': 328,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 17,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 41667,
#   'negativeIncrease': 3597,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 45300,
#   'positive': 3633,
#   'positiveIncrease': 312,
#   'recovered': 295,
#   'state': 'TN',
#   'total': 45300,
#   'totalTestResults': 45300,
#   'totalTestResultsIncrease': 3909},
#  {'_id': ObjectId('60392e3656264fee961ca845'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 127,
#   'deathIncrease': 22,
#   'fips': '48',
#   'hash': '10e1ad334b25a2430d6182ed1869f89b72eab808',
#   'hospitalized': 827,
#   'hospitalizedCumulative': 827,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 631,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 64126,
#   'negativeIncrease': 6485,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 70938,
#   'positive': 6812,
#   'positiveIncrease': 702,
#   'recovered': 38,
#   'state': 'TX',
#   'total': 70938,
#   'totalTestResults': 70938,
#   'totalTestResultsIncrease': 7187},
#  {'_id': ObjectId('60392e3656264fee961ca846'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 8,
#   'deathIncrease': 0,
#   'fips': '49',
#   'hash': '83dbc778efc9acf771c3b3a3c24fdb95eccd9723',
#   'hospitalized': 124,
#   'hospitalizedCumulative': 124,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 7,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 29287,
#   'negativeIncrease': 2672,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 30892,
#   'positive': 1605,
#   'positiveIncrease': 177,
#   'recovered': None,
#   'state': 'UT',
#   'total': 30892,
#   'totalTestResults': 30892,
#   'totalTestResultsIncrease': 2849},
#  {'_id': ObjectId('60392e3656264fee961ca847'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 51,
#   'deathIncrease': -1,
#   'fips': '51',
#   'hash': '43347a01365145c45a8187e871977110df8e3d22',
#   'hospitalized': 431,
#   'hospitalizedCumulative': 431,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 41,
#   'inIcuCumulative': 145,
#   'inIcuCurrently': None,
#   'negative': 21034,
#   'negativeIncrease': 1889,
#   'onVentilatorCumulative': 108,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 23671,
#   'positive': 2637,
#   'positiveIncrease': 230,
#   'recovered': None,
#   'state': 'VA',
#   'total': 23671,
#   'totalTestResults': 23671,
#   'totalTestResultsIncrease': 2119},
#  {'_id': ObjectId('60392e3656264fee961ca848'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 1,
#   'deathIncrease': 1,
#   'fips': '78',
#   'hash': 'f7efcce917045a165880162c7ec816f33b5f318f',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 206,
#   'negativeIncrease': 22,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 18,
#   'posNeg': 248,
#   'positive': 42,
#   'positiveIncrease': 2,
#   'recovered': 34,
#   'state': 'VI',
#   'total': 266,
#   'totalTestResults': 248,
#   'totalTestResultsIncrease': 24},
#  {'_id': ObjectId('60392e3656264fee961ca849'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 22,
#   'deathIncrease': 2,
#   'fips': '50',
#   'hash': 'e3035a258b92b434b2fe2e996f2935e60f287645',
#   'hospitalized': 45,
#   'hospitalizedCumulative': 45,
#   'hospitalizedCurrently': 29,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 6070,
#   'negativeIncrease': 687,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 6582,
#   'positive': 512,
#   'positiveIncrease': 51,
#   'recovered': 15,
#   'state': 'VT',
#   'total': 6582,
#   'totalTestResults': 6582,
#   'totalTestResultsIncrease': 738},
#  {'_id': ObjectId('60392e3656264fee961ca84a'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 310,
#   'deathIncrease': 26,
#   'fips': '53',
#   'hash': '96c1527768663458266e08a72c2f14cca2772829',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 80327,
#   'negativeIncrease': 4694,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 87918,
#   'positive': 7591,
#   'positiveIncrease': 625,
#   'recovered': None,
#   'state': 'WA',
#   'total': 87918,
#   'totalTestResults': 87918,
#   'totalTestResultsIncrease': 5319},
#  {'_id': ObjectId('60392e3656264fee961ca84b'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 68,
#   'deathIncrease': 12,
#   'fips': '55',
#   'hash': 'e9ae6b075ad9a1a7866f76c9aeddda94fa67311d',
#   'hospitalized': 624,
#   'hospitalizedCumulative': 624,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 36,
#   'inIcuCumulative': 175,
#   'inIcuCurrently': None,
#   'negative': 25169,
#   'negativeIncrease': 1310,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 27436,
#   'positive': 2267,
#   'positiveIncrease': 155,
#   'recovered': None,
#   'state': 'WI',
#   'total': 27436,
#   'totalTestResults': 27436,
#   'totalTestResultsIncrease': 1465},
#  {'_id': ObjectId('60392e3656264fee961ca84c'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 3,
#   'deathIncrease': 1,
#   'fips': '54',
#   'hash': '7c658b660d0796f3403a84ab40c4f1fcb02d9eed',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 8514,
#   'negativeIncrease': 1110,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 8838,
#   'positive': 324,
#   'positiveIncrease': 42,
#   'recovered': None,
#   'state': 'WV',
#   'total': 8838,
#   'totalTestResults': 8838,
#   'totalTestResultsIncrease': 1152},
#  {'_id': ObjectId('60392e3656264fee961ca84d'),
#   'date': 20200405,
#   'dateChecked': '2020-04-05T20:00:00Z',
#   'death': 0,
#   'deathIncrease': 0,
#   'fips': '56',
#   'hash': '521559b492dc45d4a16042c5a00a0be69fb8f96d',
#   'hospitalized': 23,
#   'hospitalizedCumulative': 23,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 3040,
#   'negativeIncrease': 95,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 3237,
#   'positive': 197,
#   'positiveIncrease': 10,
#   'recovered': 50,
#   'state': 'WY',
#   'total': 3237,
#   'totalTestResults': 3237,
#   'totalTestResultsIncrease': 105},
#  {'_id': ObjectId('60392e3656264fee961ca84e'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 5,
#   'deathIncrease': 2,
#   'fips': '02',
#   'hash': '10a0cf7d2d88dce27674dda730950a2661caa4b0',
#   'hospitalized': 16,
#   'hospitalizedCumulative': 16,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 1,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 5869,
#   'negativeIncrease': 10,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 6040,
#   'positive': 171,
#   'positiveIncrease': 14,
#   'recovered': None,
#   'state': 'AK',
#   'total': 6040,
#   'totalTestResults': 6040,
#   'totalTestResultsIncrease': 24},
#  {'_id': ObjectId('60392e3656264fee961ca84f'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 43,
#   'deathIncrease': 8,
#   'fips': '01',
#   'hash': '963802ea3a71c8b5d74fec7b17f1fb98e9547168',
#   'hospitalized': 212,
#   'hospitalizedCumulative': 212,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 212,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 9273,
#   'negativeIncrease': 1086,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 10853,
#   'positive': 1580,
#   'positiveIncrease': 148,
#   'recovered': None,
#   'state': 'AL',
#   'total': 10853,
#   'totalTestResults': 10853,
#   'totalTestResultsIncrease': 1234},
#  {'_id': ObjectId('60392e3656264fee961ca850'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 14,
#   'deathIncrease': 2,
#   'fips': '05',
#   'hash': 'b8737741e743a45a91088157640ca1a0b49adc9d',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 72,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 9627,
#   'negativeIncrease': 632,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': 23,
#   'pending': None,
#   'posNeg': 10370,
#   'positive': 743,
#   'positiveIncrease': 39,
#   'recovered': 79,
#   'state': 'AR',
#   'total': 10370,
#   'totalTestResults': 10370,
#   'totalTestResultsIncrease': 671},
#  {'_id': ObjectId('60392e3656264fee961ca851'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 0,
#   'deathIncrease': 0,
#   'fips': '60',
#   'hash': 'a7a8c57370e5f59f49e7b95394059c629156c29d',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 20,
#   'negativeIncrease': 0,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 6,
#   'posNeg': 20,
#   'positive': None,
#   'positiveIncrease': 0,
#   'recovered': None,
#   'state': 'AS',
#   'total': 26,
#   'totalTestResults': 20,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961ca852'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 52,
#   'deathIncrease': 11,
#   'fips': '04',
#   'hash': 'cfb482b3a35b4fc17924cec3a44f93a4ca0644ad',
#   'hospitalized': 297,
#   'hospitalizedCumulative': 297,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 48,
#   'inIcuCumulative': 104,
#   'inIcuCurrently': None,
#   'negative': 25141,
#   'negativeIncrease': 2237,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 27160,
#   'positive': 2019,
#   'positiveIncrease': 250,
#   'recovered': None,
#   'state': 'AZ',
#   'total': 27160,
#   'totalTestResults': 27160,
#   'totalTestResultsIncrease': 2487},
#  {'_id': ObjectId('60392e3656264fee961ca853'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 276,
#   'deathIncrease': 39,
#   'fips': '06',
#   'hash': '4a3edf69851dfa895e0e69e83fb57f41cd4c4a9f',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 2300,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': 1008,
#   'negative': 101674,
#   'negativeIncrease': 77075,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 13000,
#   'posNeg': 113700,
#   'positive': 12026,
#   'positiveIncrease': 1325,
#   'recovered': None,
#   'state': 'CA',
#   'total': 126700,
#   'totalTestResults': 113700,
#   'totalTestResultsIncrease': 78400},
#  {'_id': ObjectId('60392e3656264fee961ca854'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 111,
#   'deathIncrease': 14,
#   'fips': '08',
#   'hash': 'fec6c4719378ffbd6e56985a135056601a3d0579',
#   'hospitalized': 823,
#   'hospitalizedCumulative': 823,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 113,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 17898,
#   'negativeIncrease': 1215,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 22071,
#   'positive': 4173,
#   'positiveIncrease': 445,
#   'recovered': None,
#   'state': 'CO',
#   'total': 22071,
#   'totalTestResults': 22071,
#   'totalTestResultsIncrease': 1660},
#  {'_id': ObjectId('60392e3656264fee961ca855'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 165,
#   'deathIncrease': 34,
#   'fips': '09',
#   'hash': '6d7626dbd793cd794dc73f07b50278a1e51d9890',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 1033,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 16753,
#   'negativeIncrease': 1652,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 22029,
#   'positive': 5276,
#   'positiveIncrease': 362,
#   'recovered': None,
#   'state': 'CT',
#   'total': 22029,
#   'totalTestResults': 22029,
#   'totalTestResultsIncrease': 2014},
#  {'_id': ObjectId('60392e3656264fee961ca856'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 21,
#   'deathIncrease': 6,
#   'fips': '11',
#   'hash': 'afaf508bebd20ff5f9dd84d3011a087369a8c2b7',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 5536,
#   'negativeIncrease': 709,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 6438,
#   'positive': 902,
#   'positiveIncrease': 145,
#   'recovered': 235,
#   'state': 'DC',
#   'total': 6438,
#   'totalTestResults': 6438,
#   'totalTestResultsIncrease': 854},
#  {'_id': ObjectId('60392e3656264fee961ca857'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 14,
#   'deathIncrease': 0,
#   'fips': '10',
#   'hash': 'cc40395c305b43fd73a2e32bd1110b86b47e826b',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': 95,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 5874,
#   'negativeIncrease': 879,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 6467,
#   'positive': 593,
#   'positiveIncrease': 143,
#   'recovered': 71,
#   'state': 'DE',
#   'total': 6467,
#   'totalTestResults': 6467,
#   'totalTestResultsIncrease': 1022},
#  {'_id': ObjectId('60392e3656264fee961ca858'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 191,
#   'deathIncrease': 28,
#   'fips': '12',
#   'hash': '1f993ebcc7b85b2f8281d911efc5e3c78dda42e8',
#   'hospitalized': 1462,
#   'hospitalizedCumulative': 1462,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 175,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 90956,
#   'negativeIncrease': 8819,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': 1281,
#   'posNeg': 102067,
#   'positive': 11111,
#   'positiveIncrease': 1526,
#   'recovered': None,
#   'state': 'FL',
#   'total': 103348,
#   'totalTestResults': 102067,
#   'totalTestResultsIncrease': 10345},
#  {'_id': ObjectId('60392e3656264fee961ca859'),
#   'date': 20200404,
#   'dateChecked': '2020-04-04T20:00:00Z',
#   'death': 201,
#   'deathIncrease': 17,
#   'fips': '13',
#   'hash': '18b3449ec335447f642a8016122da3ebf65fd362',
#   'hospitalized': 1239,
#   'hospitalizedCumulative': 1239,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 81,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': 20134,
#   'negativeIncrease': 700,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 26294,
#   'positive': 6160,
#   'positiveIncrease': 329,
#   'recovered': None,
#   'state': 'GA',
#   'total': 26294,
#   'totalTestResults': 26294,
#   'totalTestResultsIncrease': 1029},
# ...
#   'negativeIncrease': None,
#   'pending': 21,
#   'posNeg': 19,
#   'positive': 0,
#   'positiveIncrease': None,
#   'state': 'CO',
#   'total': 40,
#   'totalTestResults': 19,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caea0'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '11',
#   'hash': '86141ea62e1c9a456849cf2f2196a31ac9669154',
#   'hospitalizedIncrease': None,
#   'negative': 6,
#   'negativeIncrease': None,
#   'pending': 2,
#   'posNeg': 6,
#   'positive': 0,
#   'positiveIncrease': None,
#   'state': 'DC',
#   'total': 8,
#   'totalTestResults': 6,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caea1'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '12',
#   'hash': 'd7d91ffc92fbbfad57ff361b0193d3f7df25b958',
#   'hospitalizedIncrease': 0,
#   'negative': 31,
#   'negativeIncrease': 7,
#   'pending': 69,
#   'posNeg': 40,
#   'positive': 9,
#   'positiveIncrease': 7,
#   'state': 'FL',
#   'total': 109,
#   'totalTestResults': 40,
#   'totalTestResultsIncrease': 14},
#  {'_id': ObjectId('60392e3656264fee961caea2'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '13',
#   'hash': '4247fbf0514b9492027b2328f3f2dc0b2e45f063',
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'posNeg': 2,
#   'positive': 2,
#   'positiveIncrease': 0,
#   'state': 'GA',
#   'total': 2,
#   'totalTestResults': 2,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caea3'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '17',
#   'hash': 'b4c9428d01eee9c65c8053a8cd8af2b28f9d7440',
#   'hospitalizedIncrease': 0,
#   'negative': 165,
#   'negativeIncrease': 41,
#   'pending': 27,
#   'posNeg': 170,
#   'positive': 5,
#   'positiveIncrease': 1,
#   'state': 'IL',
#   'total': 197,
#   'totalTestResults': 170,
#   'totalTestResultsIncrease': 42},
#  {'_id': ObjectId('60392e3656264fee961caea4'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '25',
#   'hash': 'ad6e88d352dfa8b8f0dd1bf41a2c506911f25bc0',
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'posNeg': 2,
#   'positive': 2,
#   'positiveIncrease': 0,
#   'state': 'MA',
#   'total': 2,
#   'totalTestResults': 2,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caea5'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '24',
#   'hash': '0d90494b997e148552cd6034f5f347e1d5afb802',
#   'hospitalizedIncrease': None,
#   'negative': 17,
#   'negativeIncrease': None,
#   'pending': 14,
#   'posNeg': 17,
#   'positive': 0,
#   'positiveIncrease': None,
#   'state': 'MD',
#   'total': 31,
#   'totalTestResults': 17,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caea6'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '26',
#   'hash': 'dd366e6ea7f02c3c5a0f1f0639f3af9396fd0905',
#   'hospitalizedIncrease': None,
#   'negative': 8,
#   'negativeIncrease': None,
#   'pending': 0,
#   'posNeg': 8,
#   'positive': 0,
#   'positiveIncrease': None,
#   'state': 'MI',
#   'total': 8,
#   'totalTestResults': 8,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caea7'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '37',
#   'hash': 'd3f8875e94e71c97de0283327b26f1feca9172e0',
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'posNeg': 1,
#   'positive': 1,
#   'positiveIncrease': 0,
#   'state': 'NC',
#   'total': 1,
#   'totalTestResults': 1,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caea8'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '31',
#   'hash': '5a0d06bda6fe7a3d859877a222126a595c97fc61',
#   'hospitalizedIncrease': None,
#   'negative': 17,
#   'negativeIncrease': None,
#   'pending': 5,
#   'posNeg': 17,
#   'positive': 0,
#   'positiveIncrease': None,
#   'state': 'NE',
#   'total': 22,
#   'totalTestResults': 17,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caea9'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '33',
#   'hash': '7e34f4dacfe1b54e984b2725002f97e08fbae32d',
#   'hospitalizedIncrease': 0,
#   'negative': 16,
#   'negativeIncrease': 6,
#   'pending': 4,
#   'posNeg': 18,
#   'positive': 2,
#   'positiveIncrease': 0,
#   'state': 'NH',
#   'total': 22,
#   'totalTestResults': 18,
#   'totalTestResultsIncrease': 6},
#  {'_id': ObjectId('60392e3656264fee961caeaa'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '34',
#   'hash': '80fa3d5297f9e2b3a46fa82bf816c002d9da0976',
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'posNeg': 1,
#   'positive': 1,
#   'positiveIncrease': None,
#   'state': 'NJ',
#   'total': 1,
#   'totalTestResults': 1,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeab'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '32',
#   'hash': 'c75ee774e7c6ee7ca098db7e8bdd27109e94471a',
#   'hospitalizedIncrease': None,
#   'negative': 14,
#   'negativeIncrease': None,
#   'posNeg': 15,
#   'positive': 1,
#   'positiveIncrease': None,
#   'state': 'NV',
#   'total': 15,
#   'totalTestResults': 15,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeac'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '36',
#   'hash': 'a5eb1a3c895ee3acd8c87b19363bab6d581b3933',
#   'hospitalizedIncrease': 0,
#   'negative': 76,
#   'negativeIncrease': 28,
#   'pending': 24,
#   'posNeg': 98,
#   'positive': 22,
#   'positiveIncrease': 16,
#   'state': 'NY',
#   'total': 122,
#   'totalTestResults': 98,
#   'totalTestResultsIncrease': 44},
#  {'_id': ObjectId('60392e3656264fee961caead'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '39',
#   'hash': '1bbd3319a4e6db7805828c6b8588392ceb2ad0f0',
#   'hospitalizedIncrease': None,
#   'negative': 7,
#   'negativeIncrease': None,
#   'pending': 3,
#   'posNeg': 7,
#   'positive': 0,
#   'positiveIncrease': None,
#   'state': 'OH',
#   'total': 10,
#   'totalTestResults': 7,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeae'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '41',
#   'hash': '99211bd19ed97ed9d4cf2ff512e5df794b13f3b8',
#   'hospitalizedIncrease': 0,
#   'negative': 45,
#   'negativeIncrease': 16,
#   'pending': 13,
#   'posNeg': 48,
#   'positive': 3,
#   'positiveIncrease': 0,
#   'state': 'OR',
#   'total': 61,
#   'totalTestResults': 48,
#   'totalTestResultsIncrease': 16},
#  {'_id': ObjectId('60392e3656264fee961caeaf'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '45',
#   'hash': '4ebec78070f45d9a5e6257d3ec1b1c20b6618cb1',
#   'hospitalizedIncrease': 0,
#   'negative': 5,
#   'negativeIncrease': 0,
#   'pending': 0,
#   'posNeg': 5,
#   'positive': 0,
#   'positiveIncrease': 0,
#   'state': 'SC',
#   'total': 5,
#   'totalTestResults': 5,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caeb0'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '47',
#   'hash': 'd6b98cde0f741d1de22a669e2bcbdd2455e12b8a',
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'posNeg': 1,
#   'positive': 1,
#   'positiveIncrease': None,
#   'state': 'TN',
#   'total': 1,
#   'totalTestResults': 1,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb1'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '48',
#   'hash': 'd7dc50f88fb103b81e0745b9f7824ed7ee6c1738',
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'posNeg': 1,
#   'positive': 1,
#   'positiveIncrease': 0,
#   'state': 'TX',
#   'total': 1,
#   'totalTestResults': 1,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caeb2'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '51',
#   'hash': 'c34566b6ec1573923e494c44f1c6b744fed9b3ad',
#   'hospitalizedIncrease': None,
#   'negative': 18,
#   'negativeIncrease': None,
#   'pending': 3,
#   'posNeg': 18,
#   'positive': 0,
#   'positiveIncrease': None,
#   'state': 'VA',
#   'total': 21,
#   'totalTestResults': 18,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb3'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'death': 11,
#   'deathIncrease': 1,
#   'fips': '53',
#   'hash': 'dfe5b036415333cb6e796cd8bde4805a159d6676',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': 0,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': None,
#   'negativeIncrease': 0,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 70,
#   'positive': 70,
#   'positiveIncrease': 31,
#   'recovered': None,
#   'state': 'WA',
#   'total': 70,
#   'totalTestResults': 70,
#   'totalTestResultsIncrease': 31},
#  {'_id': ObjectId('60392e3656264fee961caeb4'),
#   'date': 20200305,
#   'dateChecked': '2020-03-05T21:00:00Z',
#   'deathIncrease': 0,
#   'fips': '55',
#   'hash': '3620b6a39cef411a89d895ac830c5c954ce63541',
#   'hospitalizedIncrease': 0,
#   'negative': 19,
#   'negativeIncrease': 0,
#   'pending': 6,
#   'posNeg': 20,
#   'positive': 1,
#   'positiveIncrease': 0,
#   'state': 'WI',
#   'total': 26,
#   'totalTestResults': 20,
#   'totalTestResultsIncrease': 0},
#  {'_id': ObjectId('60392e3656264fee961caeb5'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '04',
#   'hash': 'f9b5336be00388e0549a6e35cfbe7ec911597df2',
#   'hospitalizedIncrease': None,
#   'negative': 27,
#   'negativeIncrease': None,
#   'pending': 5,
#   'posNeg': 29,
#   'positive': 2,
#   'positiveIncrease': None,
#   'state': 'AZ',
#   'total': 34,
#   'totalTestResults': 29,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb6'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '06',
#   'hash': 'e89c69dcaf7f202257af579a58f86c340eee886a',
#   'hospitalizedIncrease': None,
#   'negative': 462,
#   'negativeIncrease': None,
#   'posNeg': 515,
#   'positive': 53,
#   'positiveIncrease': None,
#   'state': 'CA',
#   'total': 515,
#   'totalTestResults': 515,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb7'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '12',
#   'hash': '827f5f46040136c1b1901fef08f15b03805c57f5',
#   'hospitalizedIncrease': None,
#   'negative': 24,
#   'negativeIncrease': None,
#   'pending': 16,
#   'posNeg': 26,
#   'positive': 2,
#   'positiveIncrease': None,
#   'state': 'FL',
#   'total': 42,
#   'totalTestResults': 26,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb8'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '13',
#   'hash': '5a4b97663e22df521e97a56f67c3f458eafb2e59',
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'posNeg': 2,
#   'positive': 2,
#   'positiveIncrease': None,
#   'state': 'GA',
#   'total': 2,
#   'totalTestResults': 2,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeb9'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '17',
#   'hash': 'c99302904c1de329aeb568cdf92affb6dd5921ad',
#   'hospitalizedIncrease': None,
#   'negative': 124,
#   'negativeIncrease': None,
#   'pending': 27,
#   'posNeg': 128,
#   'positive': 4,
#   'positiveIncrease': None,
#   'state': 'IL',
#   'total': 155,
#   'totalTestResults': 128,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caeba'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '25',
#   'hash': '36d8d4b1b34007477b562a078613309f63e7bd0e',
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'posNeg': 2,
#   'positive': 2,
#   'positiveIncrease': None,
#   'state': 'MA',
#   'total': 2,
#   'totalTestResults': 2,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caebb'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '37',
#   'hash': '0361de92db7c1867144ce35f0d61e1588f3a13d5',
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'posNeg': 1,
#   'positive': 1,
#   'positiveIncrease': None,
#   'state': 'NC',
#   'total': 1,
#   'totalTestResults': 1,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caebc'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '33',
#   'hash': '57c57bb5f40efbba8ab043701700324b09ac602d',
#   'hospitalizedIncrease': None,
#   'negative': 10,
#   'negativeIncrease': None,
#   'pending': 7,
#   'posNeg': 12,
#   'positive': 2,
#   'positiveIncrease': None,
#   'state': 'NH',
#   'total': 19,
#   'totalTestResults': 12,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caebd'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '36',
#   'hash': '0e095e2b3db515b00d892276e6cac6912b1e0111',
#   'hospitalizedIncrease': None,
#   'negative': 48,
#   'negativeIncrease': None,
#   'pending': 24,
#   'posNeg': 54,
#   'positive': 6,
#   'positiveIncrease': None,
#   'state': 'NY',
#   'total': 78,
#   'totalTestResults': 54,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caebe'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '41',
#   'hash': 'd63f4cf486a6d2f86062b9af1bd46955abd90cb9',
#   'hospitalizedIncrease': None,
#   'negative': 29,
#   'negativeIncrease': None,
#   'pending': 18,
#   'posNeg': 32,
#   'positive': 3,
#   'positiveIncrease': None,
#   'state': 'OR',
#   'total': 50,
#   'totalTestResults': 32,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caebf'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '45',
#   'hash': '012fa30a9958580f589eb7d1de5e5a81c327b1a5',
#   'hospitalizedIncrease': None,
#   'negative': 5,
#   'negativeIncrease': None,
#   'pending': 0,
#   'posNeg': 5,
#   'positive': 0,
#   'positiveIncrease': None,
#   'state': 'SC',
#   'total': 5,
#   'totalTestResults': 5,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caec0'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '48',
#   'hash': 'd29839e81cae6ba53df2d1a1d7bfeddfd4fc8509',
#   'hospitalizedIncrease': None,
#   'negativeIncrease': None,
#   'posNeg': 1,
#   'positive': 1,
#   'positiveIncrease': None,
#   'state': 'TX',
#   'total': 1,
#   'totalTestResults': 1,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caec1'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'death': 10,
#   'deathIncrease': None,
#   'fips': '53',
#   'hash': 'e07bd12171fed21351784c462b0dab23d8cfabbd',
#   'hospitalized': None,
#   'hospitalizedCumulative': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedIncrease': None,
#   'inIcuCumulative': None,
#   'inIcuCurrently': None,
#   'negative': None,
#   'negativeIncrease': None,
#   'onVentilatorCumulative': None,
#   'onVentilatorCurrently': None,
#   'pending': None,
#   'posNeg': 39,
#   'positive': 39,
#   'positiveIncrease': None,
#   'recovered': None,
#   'state': 'WA',
#   'total': 39,
#   'totalTestResults': 39,
#   'totalTestResultsIncrease': None},
#  {'_id': ObjectId('60392e3656264fee961caec2'),
#   'date': 20200304,
#   'dateChecked': '2020-03-04T21:00:00Z',
#   'deathIncrease': None,
#   'fips': '55',
#   'hash': 'c1fede94be9a426dc9c3b5d26d33b9f168fec21c',
#   'hospitalizedIncrease': None,
#   'negative': 19,
#   'negativeIncrease': None,
#   'pending': 6,
#   'posNeg': 20,
#   'positive': 1,
#   'positiveIncrease': None,
#   'state': 'WI',
#   'total': 26,
#   'totalTestResults': 20,
#   'totalTestResultsIncrease': None}]
